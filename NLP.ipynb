# %% [markdown]
# ## Procesamiento del lenguaje natural

# %% [markdown]
# #### Tokenizer

# %%
# Instalar usando conda install nltk o pip install nltk
import nltk
text="Bienvenid@s! En este módulo vamos a aprender sobre nlp. \
      Usaremos la biblioteca nltk. A.C.A.M.I.C.A."

# %%
from nltk.tokenize import sent_tokenize
sent_tokenize(text)
# Out:
# ['Bienvenid@s!',
#  'En este módulo vamos a aprender sobre nlp.',
#  'Usaremos la biblioteca nltk.',
#  'A.C.A.M.I.C.A.']

# %% [markdown]
# #### PunkSentenceTokenizer

# %%
import nltk

tokenizer=nltk.data.load('tokenizers/punkt/spanish.pickle')

tokenizer.tokenize(text)
# Out:
# ['Bienvenid@s!',
#  'En este módulo vamos a aprender sobre nlp.',
#  'Usaremos la biblioteca nltk.',
#  'A.C.A.M.I.C.A.']

# %% [markdown]
# #### WordTokenizer

# %%
import nltk
text=nltk.word_tokenize("Bienvenid@s! En este módulo, vamos a aprender sobre nlp. \
      Usaremos la biblioteca nltk. A.C.A.M.I.C.A.")
print(text)
# Out:
# ['Bienvenid', '@', 's', '!', 'En', 'este', 'módulo', ',', 'vamos', 'a', 'aprender', 'sobre', 'nlp', '.', 'Usaremos', 'la', 'biblioteca', 'nltk', '.', 'A.C.A.M.I.C.A', '.']

# %%
from nltk.tokenize import WordPunctTokenizer # TreebankWordTokenizer
tokenizer=WordPunctTokenizer() # TreebankWordTokenizer
tokenizer.tokenize("Bienvenid@s! En este módulo, vamos a aprender sobre nlp. \
                    Usaremos la biblioteca nltk. A.C.A.M.I.C.A.")
# Out:
# ['Bienvenid',
#  '@',
#  's',
#  '!',
#  'En',
#  'este',
#  'módulo',
#  ',',
#  'vamos',
#  'a',
#  'aprender',
#  'sobre',
#  'nlp',
#  '.',
#  'Usaremos',
#  'la',
#  'biblioteca',
#  'nltk',
#  '.',
#  'A',
#  '.',
#  'C',
#  '.',
#  'A',
#  '.',
#  'M',
#  '.',
#  'I',
#  '.',
#  'C',
#  '.',
#  'A',
#  '.']

# %%
import nltk
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer("[\w]+")
tokenizer.tokenize("Bienvenid@s! En este módulo, vamos a aprender sobre nlp. \
                    Usaremos la biblioteca nltk. A.C.A.M.I.C.A.")
# Out:
# ['Bienvenid',
#  's',
#  'En',
#  'este',
#  'módulo',
#  'vamos',
#  'a',
#  'aprender',
#  'sobre',
#  'nlp',
#  'Usaremos',
#  'la',
#  'biblioteca',
#  'nltk',
#  'A',
#  'C',
#  'A',
#  'M',
#  'I',
#  'C',
#  'A']

# %% [markdown]
# ### Normalización

# %% [markdown]
# #### lowercase

# %%
text='ESTAmos ModIFICANDO lAS LETRas'
print(text.lower())
print(text.upper())
# Out:
# estamos modificando las letras
# ESTAMOS MODIFICANDO LAS LETRAS

# %% [markdown]
# #### stopwords

# %%
import nltk
from nltk.corpus import stopwords
stops=set(stopwords.words('spanish'))

# %%
#stops

# %%
text="Vamos al parque del sur?"
word_tokens = nltk.word_tokenize(text)
[word for word in word_tokens if word not in stops]
# Out:
# ['Vamos', 'parque', 'sur', '?']

# %%
#stops

# %% [markdown]
# #### Frecuencia de palabras

# %%
from bs4 import BeautifulSoup
import urllib.request
# Obtenemos el html de la página de acámica de Data Science
response = urllib.request.urlopen('https://www.acamica.com/data-science')
html = response.read()
soup = BeautifulSoup(html,"html5lib")
text = soup.get_text()

# %%
# Tokenizamos el resultado
from nltk.tokenize import RegexpTokenizer
tokenizer=RegexpTokenizer("[\w]+")
word_tokens = tokenizer.tokenize(text)
# Sacamos stopwords y convertimos en minúscula
text_tokens = [word.lower() for word in word_tokens if word not in stops]

# %%
# Calculamos la frecuencia de las palabras
freq = nltk.FreqDist(text_tokens)
sorted_by_value = sorted(freq.items(), key=lambda kv: kv[1], reverse=True)
for key,val in sorted_by_value:
    print (str(key) + ':' + str(val))
# Out:
# 0:432
# 00:378
# null:335
# width:316
# online:311
# font:233
# margin:218
# auto:203
# color:189
# 0px:188
# 000z:186
# height:176
# flex:174
# display:168
# 2020:168
# alt:145
# 1:130
# acamica:130
# text:125
# padding:124
# https:122
# background:118
# size:117
# border:115
# url:114
# ar:109
# ds:104
# co:102
# prismic:100
# io:100
# country:99
# name:98
# title:96
# dimensions:95
# copyright:95
# images:95
# compress:95
# format:95
# startdate:93
# mode:93
# enddate:93
# city:93
# last_places:93
# schedule_days:93
# schedule_times:93
# price:93
# currency:93
# extrainfo:93
# extradata:93
# countryprice:93
# remarkprice:93
# installmentsnumber:93
# 16px:92
# mx:91
# 150:90
# position:89
# align:89
# img:87
# 2:85
# top:85
# family:81
# roboto:81
# none:79
# left:79
# min:78
# rubik:78
# s:78
# datos:76
# block:74
# max:71
# arial:69
# transform:69
# center:65
# 12:65
# direction:63
# 7:61
# 32px:58
# media:58
# box:57
# rgba:56
# 6pm:56
# 7pm:56
# weight:55
# 100:54
# 30:53
# bottom:52
# 500:52
# helvetica:51
# sans:50
# serif:50
# lunes:50
# miércoles:50
# description:50
# proyectos:45
# subtitle:45
# 11:44
# martes:43
# jueves:43
# relative:42
# aprendizaje:40
# 256:40
# false:39
# svg:39
# content:38
# early:38
# fff:37
# png:37
# 9pm:36
# muiinputbase:35
# justify:35
# jpg:35
# line:34
# 8px:34
# 05:34
# type:34
# 4:33
# solid:33
# column:33
# row:33
# mentores:33
# right:32
# radius:32
# 8pm:32
# scale:31
# ars:31
# adopter:31
# 10:30
# 6:29
# n:29
# en:28
# clases:28
# 1em:27
# 5px:27
# 50:27
# 04:27
# input:26
# hover:26
# cop:26
# carrera:25
# space:25
# ordersection:25
# ocultar:25
# absolute:24
# 20px:24
# 3:24
# habilidades:24
# presencial:24
# heading1:24
# spans:24
# items:23
# opacity:23
# style:23
# com:23
# aprender:23
# distancia:23
# data:22
# sizing:22
# 2px:22
# start:22
# aplicaciones:22
# certificación:22
# inline:21
# transition:21
# pointer:21
# 10px:21
# 52px:21
# learning:21
# videos:21
# blended:21
# analytics:21
# wrap:20
# 30px:20
# 960px:20
# u0026rect:20
# u0026w:20
# u0026h:20
# 1000:20
# key_title:20
# 5500ff:19
# cursor:19
# z:19
# index:19
# uppercase:19
# 08:19
# repeat:19
# vas:19
# aprende:19
# overflow:18
# decoration:18
# muiinputlabel:18
# cantidad:18
# crear:18
# herramientas:18
# fundamental:18
# encontrar:18
# automático:18
# expertos:18
# aprendera:18
# programa:18
# entienda:18
# puedan:18
# argentina:18
# usd:18
# other:18
# mxn:18
# list:17
# image:17
# machine:17
# plan:17
# análisis:17
# profesional:17
# experiencia:17
# 10990:17
# 32:16
# 02:16
# programación:16
# 5pm:16
# 42:15
# li:15
# 100vw:15
# 2019:15
# pm:15
# 3490:15
# 2490:15
# feat:15
# faq_title:15
# faq_subtitle:15
# 12px:14
# 4px:14
# 333:14
# 15:14
# 2c3249:14
# sc:14
# 14:14
# science:13
# shrink:13
# hidden:13
# shadow:13
# div:13
# 83c341:13
# around:13
# cover:13
# ibm:13
# preguntas:13
# 26t19:13
# cubic:12
# bezier:12
# mui:12
# placeholder:12
# 15px:12
# 000:12
# 03:12
# landings:12
# impacto:12
# diseñada:12
# distintas:12
# cómo:12
# manera:12
# eficiente:12
# predecir:12
# sedes:12
# lenguaje:12
# accesible:12
# desarrollo:12
# construye:12
# portfolio:12
# desarrollar:12
# comisión:12
# trabajar:12
# grupo:12
# dudas:12
# junto:12
# equipo:12
# inteligente:12
# algoritmos:12
# personas:12
# humanos:12
# industria:12
# todas:12
# cualquier:12
# pagar:12
# opciones:12
# tarjeta:12
# crédito:12
# débito:12
# cuenta:12
# mundo:12
# semi:12
# 890000:12
# 623000:12
# 285:12
# webkit:11
# vertical:11
# 2em:11
# 5:11
# feedback:11
# empresas:11
# meses:11
# exploración:11
# de:11
# con:11
# teoría:11
# inmuebles:11
# texto:11
# ya:11
# 06:11
# 02t19:11
# root:10
# transparent:10
# formcontrol:10
# 24px:10
# translate:10
# muiselect:10
# 25:10
# 8:10
# 9:10
# all:10
# 40px:10
# proyecto:10
# 13t19:10
# 28t15:10
# una:10
# 79:10
# reales:10
# 55:10
# servicios:10
# estudiante:10
# devoluciones:10
# personalizadas:10
# estudios_data:10
# science_v4:10
# pdf:10
# muisvgicon:9
# 200ms:9
# 0ms:9
# select:9
# label:9
# muiinput:9
# 1px:9
# 400:9
# between:9
# 24a9ff:9
# 5dd0f0:9
# ff4a6e:9
# 116:9
# ciudad:9
# comisiones:9
# acámica:8
# ms:8
# 14px:8
# white:8
# initial:8
# 50px:8
# 255:8
# 000000:8
# 600px:8
# linear:8
# gradient:8
# off:8
# 10pm:8
# 26t15:8
# 4pm:8
# 19t15:8
# t:8
# disabled:7
# underline:7
# loginbtn:7
# 18px:7
# in:7
# 300px:7
# self:7
# 48:7
# 768px:7
# 20:7
# 60px:7
# 80px:7
# watson:7
# decisiones:7
# estudiantes:7
# ver:7
# web:7
# la:7
# tecnología:7
# red:7
# colombia:7
# cor:7
# córdoba:7
# 22:7
# adopters:7
# document:7
# fill:6
# currentcolor:6
# margindense:6
# moz:6
# focus:6
# 75:6
# nowrap:6
# jss321:6
# 150px:6
# 100vh:6
# jss207:6
# 250px:6
# jss211:6
# jss34:6
# 53:6
# globant:6
# manipular:6
# infinita:6
# alcance:6
# aplica:6
# colaboración:6
# construyen:6
# día:6
# capacidad:6
# producir:6
# almacenar:6
# infinitas:6
# cantidades:6
# fuentes:6
# sea:6
# fotos:6
# reportes:6
# ventas:6
# códigos:6
# adn:6
# dilema:6
# usamos:6
# gigante:6
# adquirir:6
# conocimientos:6
# necesarias:6
# convertir:6
# informacio:6
# automatizar:6
# procesos:6
# asesorar:6
# toma:6
# podrás:6
# tomar:6
# crudo:6
# visualiza:6
# ndolos:6
# correcta:6
# entrenando:6
# modelos:6
# estadi:6
# sticos:6
# aprendan:6
# ayuden:6
# pero:6
# ma:6
# importante:6
# podra:6
# generar:6
# propias:6
# contara:6
# responderlas:6
# hs:6
# básica:6
# leer:6
# plataforma:6
# soporte:6
# cada:6
# diploma:6
# validado:6
# mercado:6
# libre:6
# herramienta:6
# modernos:6
# te:6
# enseñaremos:6
# utilizar:6
# python:6
# moderno:6
# historia:6
# pueden:6
# contar:6
# combinando:6
# técnicas:6
# estadísticas:6
# visualización:6
# permite:6
# patrones:6
# comportamientos:6
# aprendido:6
# modernas:6
# procesamiento:6
# natural:6
# asistentes:6
# voz:6
# siri:6
# alexa:6
# sistemas:6
# recomendación:6
# plataformas:6
# netflix:6
# spotify:6
# youtube:6
# basado:6
# trabajando:6
# desafíos:6
# prácticos:6
# servirán:6
# armar:6
# inscríbete:6
# mediante:6
# videoconferencia:6
# contenido:6
# teórico:6
# horas:6
# clase:6
# práctico:6
# realizar:6
# dinámicas:6
# resolver:6
# innovadoras:6
# compañeros:6
# guiados:6
# precios:6
# exploracio:6
# visualizacio:6
# luego:6
# modelo:6
# inteligencia:6
# artificial:6
# prediga:6
# automa:6
# ticamente:6
# costo:6
# barrio:6
# regresio:6
# lineal:6
# usando:6
# dataset:6
# real:6
# up:6
# properati:6
# sentimientos:6
# lea:6
# reviews:6
# escritas:6
# emociones:6
# procesara:6
# hara:6
# sentimiento:6
# miles:6
# conocera:6
# redes:6
# neuronales:6
# usar:6
# tecnologi:6
# capaz:6
# conexiones:6
# sema:6
# nticas:6
# base:6
# preferencias:6
# recomiende:6
# nuevas:6
# peli:6
# culas:6
# cnicas:6
# clustering:6
# svd:6
# computadora:6
# mejor:6
# mismos:6
# cloud:6
# utilizarlo:6
# descubrimiento:6
# cualquiera:6
# transformar:6
# valor:6
# agregado:6
# moderna:6
# presenciales:6
# contenidos:6
# avances:6
# aprendas:6
# flexibilidad:6
# progreso:6
# esfuerzo:6
# va:6
# mano:6
# necesidades:6
# validación:6
# gigantes:6
# tecnológicos:6
# mentoría:6
# grupos:6
# reducidos:6
# guía:6
# evacuar:6
# robustos:6
# haciendo:6
# devolución:6
# código:6
# humanas:6
# importancia:6
# complementarias:6
# destaques:6
# ámbito:6
# frecuentes:6
# puedo:6
# inscripción:6
# y:6
# cuotas:6
# según:6
# país:6
# residencia:6
# cuentas:6
# bancaria:6
# cbu:6
# transferencia:6
# depósito:6
# efectivo:6
# rapipago:6
# resto:6
# ofrecen:6
# financiación:6
# carreras:6
# mantenemos:6
# compromiso:6
# interesadas:6
# alcanzar:6
# objetivo:6
# formación:6
# por:6
# ofrecemos:6
# posibilidad:6
# mensualidades:6
# fijas:6
# interés:6
# intermediarios:6
# hay:6
# diferencias:6
# programas:6
# hemos:6
# trabajado:6
# ambas:6
# experiencias:6
# equivalentes:6
# formadores:6
# tamaño:6
# encuentros:6
# estudios:6
# comunidad:6
# propuestas:6
# extra:6
# mismas:6
# única:6
# diferencia:6
# modalidad:6
# asistes:6
# espacio:6
# físico:6
# mientras:6
# conectas:6
# necesario:6
# vivir:6
# gran:6
# formarte:6
# puedes:6
# hacerlo:6
# lugar:6
# 9990:6
# career:6
# true:6
# cdn:6
# var:6
# important:5
# 26:5
# appearance:5
# after:5
# events:5
# error:5
# before:5
# muiformlabel:5
# 1024px:5
# jss323:5
# 600:5
# fixed:5
# 1s:5
# ease:5
# 13px:5
# bold:5
# 200px:5
# 180deg:5
# 18:5
# jss69:5
# jss72:5
# 27:5
# 07:5
# bog:5
# bogotá:5
# 299:5
# 24t12:5
# bue:5
# buenos:5
# aires:5
# 16:5
# 17:5
# 07t15:5
# 15t03:5
# 15t15:5
# 20t15:5
# showhide:5
# video_src:5
# image_head:5
# 1440:5
# 680:5
# 7ed9df880288e0dd440fd7edf119f0a322649b03_proyecto1:5
# imagen:5
# top_title:5
# login_button:5
# title_header:5
# primary_button_hero_name:5
# ahora:5
# primary_button_hero_url:5
# secundary_button_hero_name:5
# subtitle_header:5
# title_collaborators:5
# careerlongname:5
# collaborators_images:5
# partner_img:5
# 300:5
# 2f5bd2a240:5
# 9e29:5
# 49f6:5
# a9e4:5
# 5ff035a6ec57_companies:5
# section_name_1:5
# caracteristicas:5
# section_title_1:5
# futuro:5
# section_subtitle_1:5
# career_description:5
# hoy:5
# career_duration:5
# career_dedication:5
# semana:5
# career_requeriments:5
# matemática:5
# inglés:5
# section_name_2:5
# section_title_2:5
# section_subtitle_2:5
# feature_items_list:5
# 2f1e7126fd:5
# 0cf9:5
# 4027:5
# 9674:5
# 43b7718232b6_ds:5
# crea:5
# 2fc3f87158:5
# faa0:5
# 4c41:5
# 8168:5
# 8d24f10f1bb8_ds:5
# interactiva:5
# 2f29b533b7:5
# e9f9:5
# 4415:5
# a121:5
# 830f58dd12bf_ds:5
# support:5
# chat:5
# diario:5
# 96:5
# 2f26e2b600:5
# 06f7:5
# 4e83:5
# 8137:5
# 1bb80cbe5167_ds:5
# recibe:5
# entregas:5
# 2fa93c01d9:5
# 3e54:5
# 4454:5
# 9600:5
# e41322c7ca3b_ds:5
# team:5
# videollamadas:5
# 2f84eb7097:5
# 8705:5
# 46aa:5
# 9b97:5
# 0d7c6cb236b5_ds:5
# certificate:5
# entrega:5
# section_name_3:5
# section_title_3:5
# section_subtitle_3:5
# feature_big_items:5
# d58e3f3e:5
# be1d:5
# 4d95:5
# 83b8:5
# 3b64e3f64dec_python:5
# programar:5
# 4ea9aa59:5
# c97d:5
# 43c3:5
# 80a4:5
# c01472eda52c_report:5
# aprenderás:5
# 42bc2399:5
# ca96:5
# 40f3:5
# aa44:5
# 04d793b3c7f0_machine:5
# el:5
# 5b3cfa02:5
# daf2:5
# 4c35:5
# 8ccd:5
# c1c891249e60_voice:5
# assistant:5
# utilizaremos:5
# section_name_4:5
# section_title_4:5
# section_subtitle_4:5
# img_box_01:5
# 576:5
# 389:5
# 21dad6ff5ca27df5a8b871311fb33d872d8bf6a6_landing:5
# img_title_01:5
# img_subtitle_01:5
# súmate:5
# img_box_02:5
# 1200:5
# 654:5
# 16ad5d02162aa8594de0e2554b91b4f3821d1d4f_landing:5
# img_title_02:5
# interactivo:5
# img_subtitle_02:5
# vive:5
# img_box_03:5
# 604:5
# 387:5
# 198fbb4bd367637c5807e371a906eb9bd0d85d22_landing:5
# img_title_03:5
# img_subtitle_03:5
# projects:5
# 22debf9a37062048b1f1846a06b119c65c97c712_1:5
# predicción:5
# realizara:5
# 2e345adde52acba6022d0b76d6ae7986151ba63a_2:5
# construira:5
# 5ac6bd3a51b43e6fb64804d4f4ca88ddbc10f7e9_3:5
# recomendador:5
# películas:5
# creara:5
# 0249c890b879d86aca66c01153e114873dc6f2ff_4:5
# puesta:5
# producción:5
# pondra:5
# section_name_5:5
# section_title_5:5
# section_subtitle_5:5
# career_reference:5
# híbrido:5
# confía:5
# personalizada:5
# realiza:5
# laborales:5
# entendemos:5
# section_name_6:5
# faqs:5
# section_title_6:5
# section_subtitle_6:5
# faqs_landing:5
# career_program:5
# link_type:5
# kind:5
# 17e6ed9c:5
# 968b:5
# 4710:5
# b36f:5
# ff5064439d9a_plan:5
# 2531757:5
# ordergroup:5
# body:4
# f44336:4
# inherit:4
# calc:4
# 6px:4
# 3px:4
# not:4
# filled:4
# outlined:4
# muiformcontrol:4
# span:4
# jss324:4
# normal:4
# 624px:4
# end:4
# jss116:4
# jss130:4
# g:4
# jss203:4
# 4em:4
# 390px:4
# 256px:4
# jss229:4
# 80:4
# jss234:4
# jss236:4
# jss194:4
# jss3:4
# primarybuttonhero:4
# jss66:4
# jss88:4
# jss91:4
# jss218:4
# 8em:4
# 1149000:4
# 01:4
# 20t19:4
# 15t12:4
# 1039000:4
# 728000:4
# 10t19:4
# 13t12:4
# 12t19:4
# 25t03:4
# méxico:4
# 07t03:4
# 21:4
# 22t03:4
# 02t03:4
# 11pm:4
# 05t15:4
# 24:4
# 2022:4
# 04t15:4
# 11t15:4
# 12t15:4
# 28:4
# 13t15:4
# 23t15:4
# 29:4
# 18t15:4
# 25t15:4
# 31:4
# 16t15:4
# 03t15:4
# 27t15:4
# sectionname1:4
# sectionname2:4
# sectionname3:4
# sectionname4:4
# sectionname6:4
# function:4
# 54:3
# outline:3
# 87:3
# 7px:3
# scalex:3
# focused:3
# multiple:3
# icon:3
# 35px:3
# jss319:3
# 50f:3
# flow:3
# 5em:3
# jss115:3
# 46px:3
# jss131:3
# 51:3
# jss151:3
# 035:3
# 320px:3
# 9em:3
# 2s:3
# jss240:3
# jss233:3
# 230px:3
# iframe:3
# h3:3
# jss193:3
# 118deg:3
# 131:3
# 195:3
# 65:3
# 142:3
# 59:3
# 247:3
# jss12:3
# jss17:3
# jss21:3
# 90px:3
# 5s:3
# p:3
# jss77:3
# 300ms:3
# jss81:3
# jss89:3
# 130px:3
# jss170:3
# jss314:3
# lográ:3
# pueda:3
# 30pm:3
# 03t19:3
# 19:3
# 805000:3
# logra:3
# page:3
# www:3
# window:3
# console:3
# methods:3
# user:2
# paper:2
# 1rem:2
# 1875em:2
# 38:2
# default:2
# multiline:2
# fullwidth:2
# textfield:2
# 4400cc:2
# letter:2
# spacing:2
# origin:2
# 17px:2
# muimenu:2
# ellipsis:2
# smoothing:2
# fafafa:2
# jss316:2
# 33:2
# 666:2
# jss149:2
# jss150:2
# jss133:2
# jss134:2
# 92px:2
# jss107:2
# jss112:2
# jss124:2
# jss125:2
# 9px:2
# middle:2
# jss156:2
# jss157:2
# jss177:2
# 360px:2
# jss205:2
# jss166:2
# 240b2e:2
# jss206:2
# jss208:2
# jss210:2
# 310px:2
# jss212:2
# jss214:2
# jss306:2
# jss160:2
# jss162:2
# jss163:2
# jss164:2
# jss165:2
# jss238:2
# jss239:2
# jss241:2
# widht:2
# jss242:2
# jss231:2
# jss235:2
# object:2
# plus:2
# j827dged:2
# play:2
# jss237:2
# 45:2
# jss201:2
# jss202:2
# ffffff:2
# 280px:2
# 36px:2
# jss1:2
# jss2:2
# sizig:2
# borderbox:2
# 83c34111:2
# norepeat:2
# jss14:2
# jss18:2
# jss19:2
# 1033px:2
# jss22:2
# jss27:2
# jss29:2
# jss30:2
# 160px:2
# band_exp:2
# jss37:2
# f4f4f4:2
# jss38:2
# jss45:2
# jss46:2
# 350px:2
# 215px:2
# jss50:2
# 60:2
# jss55:2
# 00000088:2
# mentordescription:2
# jss56:2
# 70px:2
# hsla:2
# jss64:2
# jss65:2
# 44:2
# 73:2
# jss70:2
# jss71:2
# 75px:2
# jss74:2
# jss76:2
# 455:2
# 515:2
# 955:2
# 203:2
# 68:2
# 85:2
# 69:2
# jss90:2
# jss92:2
# 190px:2
# jss167:2
# jss168:2
# jss169:2
# of:2
# jss171:2
# jss216:2
# jss217:2
# jss219:2
# jss220:2
# jss226:2
# 54px:2
# 100px:2
# jss227:2
# jss309:2
# jss310:2
# jss311:2
# jss312:2
# jss313:2
# jss315:2
# ahoraen:2
# fechas:2
# med:2
# 05t12:2
# 19t03:2
# 09:2
# mex:2
# 3890:2
# 2790:2
# 05t03:2
# 11990:2
# aprendé:2
# auth:2
# dev:2
# prod:2
# signed:2
# sl:2
# login:2
# eg5r2nmaoprzxcmzubdalph0gtkughow:2
# if:2
# invoked:2
# segment:2
# factory:2
# return:2
# load:2
# script:2
# js:2
# custom:1
# 5rem:1
# colorprimary:1
# colorsecondary:1
# coloraction:1
# colorerror:1
# colordisabled:1
# fontsizeinherit:1
# fontsizesmall:1
# 25rem:1
# fontsizelarge:1
# 1875rem:1
# muipopover:1
# x:1
# tap:1
# highlight:1
# invalid:1
# search:1
# inputmargindense:1
# inputselect:1
# inputmultiline:1
# resize:1
# inputtypesearch:1
# 00a0:1
# dotted:1
# 00938em:1
# asterisk:1
# 21px:1
# animated:1
# marginnormal:1
# 96px:1
# scrolling:1
# touch:1
# expand:1
# option:1
# optgroup:1
# selectmenu:1
# html:1
# antialiased:1
# osx:1
# grayscale:1
# strong:1
# b:1
# bolder:1
# 875rem:1
# 43:1
# 01071em:1
# print:1
# backdrop:1
# jss317:1
# jss318:1
# bettween:1
# jss320:1
# word:1
# breakword:1
# jss322:1
# jss325:1
# 618px:1
# jss106:1
# jss108:1
# jss109:1
# jss110:1
# jss111:1
# listonoff:1
# jss113:1
# jss114:1
# 260px:1
# jss117:1
# jss118:1
# jss119:1
# jss120:1
# jss121:1
# jss122:1
# jss123:1
# jss126:1
# jss127:1
# jss128:1
# jss129:1
# 240px:1
# jss132:1
# rgb:1
# jss152:1
# jss153:1
# jss154:1
# jss155:1
# jss144:1
# jss145:1
# jss146:1
# jss147:1
# jss148:1
# jss159:1
# 80vw:1
# jss158:1
# 17em:1
# jss178:1
# jss179:1
# jss180:1
# 68px:1
# jss181:1
# jss182:1
# jss183:1
# jss184:1
# jss204:1
# 444444:1
# 696969:1
# jss209:1
# jss213:1
# jss307:1
# jss308:1
# sticky:1
# 178px:1
# jss161:1
# 180px:1
# 082:1
# jss230:1
# jss232:1
# 25s:1
# 110px:1
# 25px:1
# jss195:1
# jss196:1
# jss197:1
# jss198:1
# jss199:1
# jss200:1
# jss185:1
# jss186:1
# jss187:1
# 290px:1
# jss188:1
# jss189:1
# jss190:1
# 90:1
# jss191:1
# jss192:1
# 232px:1
# jss4:1
# jss5:1
# jss6:1
# jss7:1
# jss8:1
# 41px:1
# jss9:1
# jss10:1
# jss11:1
# jss13:1
# 550px:1
# jss15:1
# jss16:1
# jss20:1
# jss23:1
# jss24:1
# jss25:1
# jss26:1
# jss28:1
# jss31:1
# jss32:1
# jss33:1
# jss35:1
# jss36:1
# jss39:1
# jss40:1
# 45px:1
# jss41:1
# jss42:1
# jss43:1
# jss44:1
# clear:1
# both:1
# indent:1
# jss47:1
# jss48:1
# jss49:1
# jss51:1
# 340px:1
# jss52:1
# jss53:1
# jss54:1
# jss57:1
# ped_n30a0788:1
# jss58:1
# tec_n30a0139:1
# jss59:1
# tec_n30a0145:1
# jss60:1
# n30a0815_:1
# jss61:1
# tec_img_5318:1
# jss62:1
# tec_n30a0986:1
# jss63:1
# 450px:1
# jss67:1
# jss68:1
# jss73:1
# jss75:1
# 222:1
# 645:1
# 045:1
# 355:1
# jss78:1
# casa_naranja:1
# jss79:1
# offices:1
# bogota:1
# aei:1
# arquitectura:1
# interiores:1
# 700x467:1
# jss80:1
# 940x705:1
# enterprise:1
# ont:1
# jss82:1
# jss83:1
# jss84:1
# jss85:1
# jss86:1
# jss87:1
# postion:1
# 400px:1
# jss93:1
# 1040px:1
# jss94:1
# jss95:1
# jss96:1
# jss97:1
# jss98:1
# 370px:1
# jss99:1
# 220px:1
# 405px:1
# jss100:1
# 560px:1
# 170px:1
# jss101:1
# 140px:1
# 710px:1
# jss102:1
# 804px:1
# 330px:1
# jss104:1
# 40:1
# h4:1
# 28px:1
# tansform:1
# flexstart:1
# jss105:1
# 1280px:1
# 1110px:1
# first:1
# last:1
# jss172:1
# 800px:1
# 144:1
# 149:1
# 161:1
# jss173:1
# jss174:1
# jss175:1
# jss176:1
# jss215:1
# f1f2f4:1
# 93:1
# jss221:1
# jss222:1
# jss223:1
# jss224:1
# jss225:1
# 6b7c93:1
# 46:1
# jss228:1
# 385px:1
# 182px:1
# logo_acamicalogo_acamicamentoresequipocarreras:1
# estudiantescarreradata:1
# scienceaprendé:1
# condata:1
# sciencesobre:1
# carreraplan:1
# estudioqué:1
# aprenderexperienciapróximas:1
# iniciopreguntas:1
# frecuentesaplica:1
# ahorauna:1
# futurohoy:1
# duración7:1
# mesesdedicación:1
# estimada14:1
# semanarequisitosmatemática:1
# inglésaprendizaje:1
# proyectoscrea:1
# realesteoría:1
# interactivavideos:1
# onlineservicios:1
# estudiantechat:1
# diariodevoluciones:1
# personalizadasrecibe:1
# entregasclases:1
# mentoresya:1
# videollamadascertificaciónentrega:1
# globantver:1
# estudiosaplica:1
# deprogramaciónprogramar:1
# datosaprenderás:1
# learningel:1
# aplicacionesutilizaremos:1
# profesionalcon:1
# distanciasúmate:1
# interactivovive:1
# mentoresaprende:1
# 1predicción:1
# inmueblesrealizara:1
# 2análisis:1
# textoconstruira:1
# 3recomendador:1
# películascreara:1
# 4puesta:1
# producciónpondra:1
# ayuda:1
# información:1
# fácil:1
# acceso:1
# verse:1
# explorarse:1
# conectarse:1
# paloma:1
# analyst:1
# medalliapalomabrianmartínpróximas:1
# iniciofiltrar:1
# mes:1
# inicio:1
# híbridouna:1
# empresasconfía:1
# personalizadaaprende:1
# realesrealiza:1
# laboralesentendemos:1
# frecuentesquiero:1
# comenzar:1
# ahorasuscríbete:1
# newsletter:1
# recibir:1
# novedades:1
# próximas:1
# comisionesenviarcarrerasdesarrollo:1
# full:1
# stackdiseño:1
# ux:1
# uidata:1
# sciencefront:1
# avanzado:1
# reactacámicaequipomentorespreguntas:1
# frecuentescontáctanosiniciar:1
# consultasoporte:1
# medios:1
# acámicatérminosprivacidad:1
# datamanager:1
# props:1
# pageprops:1
# locations:1
# 639000:1
# 6499000:1
# 8549:1
# 607000:1
# 13299:1
# 55899:1
# 1090000:1
# 6175000:1
# 1704:1
# 8999:1
# 13999:1
# 58799:1
# 17t19:1
# medellín:1
# 6290:1
# 4390:1
# 13:1
# 12t12:1
# 01t03:1
# 09t19:1
# 08t03:1
# 20t03:1
# 28t03:1
# medellin:1
# 26t03:1
# 23t03:1
# 03t03:1
# 990000:1
# 693000:1
# 22t15:1
# 02t15:1
# contents:1
# querycountry:1
# careercontent:1
# query:1
# buildid:1
# iheocvamxigwgjn_tv9et:1
# runtimeconfig:1
# zendesk:1
# key:1
# 104ac87e:1
# cd4e:1
# 44f6:1
# 9636:1
# ec8bccf6e2c9:1
# enabled:1
# port:1
# 3000:1
# servername:1
# server:1
# auth0_client_id:1
# ul45jupc2qwpqw8b31tovtvmats8rpl5:1
# auth0_client_domain:1
# auth0_realm:1
# auth0_redirect_uri:1
# login_service_endpoint:1
# acamica_dashboard:1
# acamica_login:1
# session_domain:1
# checkout_service_domain:1
# checkin:1
# student_service_domain:1
# students:1
# sentry_dsn:1
# 872cc2f479a74d15b10b90c455d7ac20:1
# logs:1
# net:1
# git_hash:1
# segment_key:1
# initialize:1
# snippet:1
# included:1
# twice:1
# else:1
# tracksubmit:1
# trackclick:1
# tracklink:1
# trackform:1
# pageview:1
# identify:1
# reset:1
# group:1
# track:1
# ready:1
# alias:1
# debug:1
# once:1
# on:1
# array:1
# prototype:1
# slice:1
# call:1
# arguments:1
# unshift:1
# push:1
# for:1
# length:1
# createelement:1
# javascript:1
# async:1
# src:1
# v1:1
# getelementsbytagname:1
# parentnode:1
# insertbefore:1
# _loadoptions:1
# snippet_version:1

# %% [markdown]
# #### N-gramas

# %%
from nltk import ngrams

n = 2
bigrams = ngrams(text_tokens, n)

for grams in bigrams:
    print(grams)
# Out:
# ('body', 'margin')
# ('margin', '0')
# ('0', 'font')
# ('font', 'size')
# ('size', '16px')
# ('16px', 'important')
# ('important', 'custom')
# ('custom', 'carrera')
# ('carrera', 'data')
# ('data', 'science')
# ('science', 'acámica')
# ('acámica', 'muisvgicon')
# ('muisvgicon', 'root')
# ('root', 'fill')
# ('fill', 'currentcolor')
# ('currentcolor', 'width')
# ('width', '1em')
# ('1em', 'height')
# ('height', '1em')
# ('1em', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'font')
# ('font', 'size')
# ('size', '1')
# ('1', '5rem')
# ('5rem', 'transition')
# ('transition', 'fill')
# ('fill', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '4')
# ('4', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'flex')
# ('flex', 'shrink')
# ('shrink', '0')
# ('0', 'user')
# ('user', 'select')
# ('select', 'none')
# ('none', 'muisvgicon')
# ('muisvgicon', 'colorprimary')
# ('colorprimary', 'color')
# ('color', '5500ff')
# ('5500ff', 'muisvgicon')
# ('muisvgicon', 'colorsecondary')
# ('colorsecondary', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '4')
# ('4', 'muisvgicon')
# ('muisvgicon', 'coloraction')
# ('coloraction', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '54')
# ('54', 'muisvgicon')
# ('muisvgicon', 'colorerror')
# ('colorerror', 'color')
# ('color', 'f44336')
# ('f44336', 'muisvgicon')
# ('muisvgicon', 'colordisabled')
# ('colordisabled', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '26')
# ('26', 'muisvgicon')
# ('muisvgicon', 'fontsizeinherit')
# ('fontsizeinherit', 'font')
# ('font', 'size')
# ('size', 'inherit')
# ('inherit', 'muisvgicon')
# ('muisvgicon', 'fontsizesmall')
# ('fontsizesmall', 'font')
# ('font', 'size')
# ('size', '1')
# ('1', '25rem')
# ('25rem', 'muisvgicon')
# ('muisvgicon', 'fontsizelarge')
# ('fontsizelarge', 'font')
# ('font', 'size')
# ('size', '2')
# ('2', '1875rem')
# ('1875rem', 'muipopover')
# ('muipopover', 'paper')
# ('paper', 'outline')
# ('outline', '0')
# ('0', 'position')
# ('position', 'absolute')
# ('absolute', 'max')
# ('max', 'width')
# ('width', 'calc')
# ('calc', '100')
# ('100', '32px')
# ('32px', 'min')
# ('min', 'width')
# ('width', '16px')
# ('16px', 'max')
# ('max', 'height')
# ('height', 'calc')
# ('calc', '100')
# ('100', '32px')
# ('32px', 'min')
# ('min', 'height')
# ('height', '16px')
# ('16px', 'overflow')
# ('overflow', 'x')
# ('x', 'hidden')
# ('hidden', 'overflow')
# ('overflow', 'auto')
# ('auto', 'muiinputbase')
# ('muiinputbase', 'root')
# ('root', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '87')
# ('87', 'cursor')
# ('cursor', 'text')
# ('text', 'display')
# ('display', 'inline')
# ('inline', 'flex')
# ('flex', 'position')
# ('position', 'relative')
# ('relative', 'font')
# ('font', 'size')
# ('size', '1rem')
# ('1rem', 'box')
# ('box', 'sizing')
# ('sizing', 'border')
# ('border', 'box')
# ('box', 'align')
# ('align', 'items')
# ('items', 'center')
# ('center', 'font')
# ('font', 'family')
# ('family', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '1875em')
# ('1875em', 'muiinputbase')
# ('muiinputbase', 'root')
# ('root', 'mui')
# ('mui', 'disabled')
# ('disabled', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '38')
# ('38', 'cursor')
# ('cursor', 'default')
# ('default', 'muiinputbase')
# ('muiinputbase', 'multiline')
# ('multiline', 'padding')
# ('padding', '6px')
# ('6px', '0')
# ('0', '7px')
# ('7px', 'muiinputbase')
# ('muiinputbase', 'multiline')
# ('multiline', 'muiinputbase')
# ('muiinputbase', 'margindense')
# ('margindense', 'padding')
# ('padding', 'top')
# ('top', '3px')
# ('3px', 'muiinputbase')
# ('muiinputbase', 'fullwidth')
# ('fullwidth', 'width')
# ('width', '100')
# ('100', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'font')
# ('font', 'inherit')
# ('inherit', 'color')
# ('color', 'currentcolor')
# ('currentcolor', 'width')
# ('width', '100')
# ('100', 'border')
# ('border', '0')
# ('0', 'height')
# ('height', '1')
# ('1', '1875em')
# ('1875em', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '6px')
# ('6px', '0')
# ('0', '7px')
# ('7px', 'min')
# ('min', 'width')
# ('width', '0')
# ('0', 'background')
# ('background', 'none')
# ('none', 'box')
# ('box', 'sizing')
# ('sizing', 'content')
# ('content', 'box')
# ('box', 'webkit')
# ('webkit', 'tap')
# ('tap', 'highlight')
# ('highlight', 'color')
# ('color', 'transparent')
# ('transparent', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'webkit')
# ('webkit', 'input')
# ('input', 'placeholder')
# ('placeholder', 'color')
# ('color', 'currentcolor')
# ('currentcolor', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'transition')
# ('transition', 'opacity')
# ('opacity', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '4')
# ('4', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'moz')
# ('moz', 'placeholder')
# ('placeholder', 'color')
# ('color', 'currentcolor')
# ('currentcolor', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'transition')
# ('transition', 'opacity')
# ('opacity', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '4')
# ('4', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'ms')
# ('ms', 'input')
# ('input', 'placeholder')
# ('placeholder', 'color')
# ('color', 'currentcolor')
# ('currentcolor', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'transition')
# ('transition', 'opacity')
# ('opacity', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '4')
# ('4', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'ms')
# ('ms', 'input')
# ('input', 'placeholder')
# ('placeholder', 'color')
# ('color', 'currentcolor')
# ('currentcolor', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'transition')
# ('transition', 'opacity')
# ('opacity', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '4')
# ('4', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'focus')
# ('focus', 'outline')
# ('outline', '0')
# ('0', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'invalid')
# ('invalid', 'box')
# ('box', 'shadow')
# ('shadow', 'none')
# ('none', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'webkit')
# ('webkit', 'search')
# ('search', 'decoration')
# ('decoration', 'webkit')
# ('webkit', 'appearance')
# ('appearance', 'none')
# ('none', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'mui')
# ('mui', 'disabled')
# ('disabled', 'opacity')
# ('opacity', '1')
# ('1', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'webkit')
# ('webkit', 'input')
# ('input', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', 'important')
# ('important', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'moz')
# ('moz', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', 'important')
# ('important', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'ms')
# ('ms', 'input')
# ('input', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', 'important')
# ('important', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'ms')
# ('ms', 'input')
# ('input', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', 'important')
# ('important', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'focus')
# ('focus', 'webkit')
# ('webkit', 'input')
# ('input', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'focus')
# ('focus', 'moz')
# ('moz', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'focus')
# ('focus', 'ms')
# ('ms', 'input')
# ('input', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'label')
# ('label', 'data')
# ('data', 'shrink')
# ('shrink', 'false')
# ('false', 'muiinputbase')
# ('muiinputbase', 'formcontrol')
# ('formcontrol', 'muiinputbase')
# ('muiinputbase', 'input')
# ('input', 'focus')
# ('focus', 'ms')
# ('ms', 'input')
# ('input', 'placeholder')
# ('placeholder', 'opacity')
# ('opacity', '0')
# ('0', '42')
# ('42', 'muiinputbase')
# ('muiinputbase', 'inputmargindense')
# ('inputmargindense', 'padding')
# ('padding', 'top')
# ('top', '3px')
# ('3px', 'muiinputbase')
# ('muiinputbase', 'inputselect')
# ('inputselect', 'padding')
# ('padding', 'right')
# ('right', '24px')
# ('24px', 'muiinputbase')
# ('muiinputbase', 'inputmultiline')
# ('inputmultiline', 'height')
# ('height', 'auto')
# ('auto', 'resize')
# ('resize', 'none')
# ('none', 'padding')
# ('padding', '0')
# ('0', 'muiinputbase')
# ('muiinputbase', 'inputtypesearch')
# ('inputtypesearch', 'moz')
# ('moz', 'appearance')
# ('appearance', 'textfield')
# ('textfield', 'webkit')
# ('webkit', 'appearance')
# ('appearance', 'textfield')
# ('textfield', 'muiinput')
# ('muiinput', 'root')
# ('root', 'position')
# ('position', 'relative')
# ('relative', 'label')
# ('label', 'muiinput')
# ('muiinput', 'formcontrol')
# ('formcontrol', 'margin')
# ('margin', 'top')
# ('top', '16px')
# ('16px', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'after')
# ('after', 'left')
# ('left', '0')
# ('0', 'right')
# ('right', '0')
# ('0', 'bottom')
# ('bottom', '0')
# ('0', 'content')
# ('content', 'position')
# ('position', 'absolute')
# ('absolute', 'transform')
# ('transform', 'scalex')
# ('scalex', '0')
# ('0', 'transition')
# ('transition', 'transform')
# ('transform', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'border')
# ('border', 'bottom')
# ('bottom', '2px')
# ('2px', 'solid')
# ('solid', '4400cc')
# ('4400cc', 'pointer')
# ('pointer', 'events')
# ('events', 'none')
# ('none', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'mui')
# ('mui', 'focused')
# ('focused', 'after')
# ('after', 'transform')
# ('transform', 'scalex')
# ('scalex', '1')
# ('1', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'mui')
# ('mui', 'error')
# ('error', 'after')
# ('after', 'transform')
# ('transform', 'scalex')
# ('scalex', '1')
# ('1', 'border')
# ('border', 'bottom')
# ('bottom', 'color')
# ('color', 'f44336')
# ('f44336', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'before')
# ('before', 'left')
# ('left', '0')
# ('0', 'right')
# ('right', '0')
# ('0', 'bottom')
# ('bottom', '0')
# ('0', 'content')
# ('content', '00a0')
# ('00a0', 'position')
# ('position', 'absolute')
# ('absolute', 'transition')
# ('transition', 'border')
# ('border', 'bottom')
# ('bottom', 'color')
# ('color', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '4')
# ('4', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'border')
# ('border', 'bottom')
# ('bottom', '1px')
# ('1px', 'solid')
# ('solid', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '42')
# ('42', 'pointer')
# ('pointer', 'events')
# ('events', 'none')
# ('none', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'hover')
# ('hover', 'not')
# ('not', 'mui')
# ('mui', 'disabled')
# ('disabled', 'before')
# ('before', 'border')
# ('border', 'bottom')
# ('bottom', '2px')
# ('2px', 'solid')
# ('solid', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '87')
# ('87', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'mui')
# ('mui', 'disabled')
# ('disabled', 'before')
# ('before', 'border')
# ('border', 'bottom')
# ('bottom', 'style')
# ('style', 'dotted')
# ('dotted', 'media')
# ('media', 'hover')
# ('hover', 'none')
# ('none', 'muiinput')
# ('muiinput', 'underline')
# ('underline', 'hover')
# ('hover', 'not')
# ('not', 'mui')
# ('mui', 'disabled')
# ('disabled', 'before')
# ('before', 'border')
# ('border', 'bottom')
# ('bottom', '1px')
# ('1px', 'solid')
# ('solid', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '42')
# ('42', 'muiformlabel')
# ('muiformlabel', 'root')
# ('root', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '54')
# ('54', 'padding')
# ('padding', '0')
# ('0', 'font')
# ('font', 'size')
# ('size', '1rem')
# ('1rem', 'font')
# ('font', 'family')
# ('family', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '400')
# ('400', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', 'letter')
# ('letter', 'spacing')
# ('spacing', '0')
# ('0', '00938em')
# ('00938em', 'muiformlabel')
# ('muiformlabel', 'root')
# ('root', 'mui')
# ('mui', 'focused')
# ('focused', 'color')
# ('color', '4400cc')
# ('4400cc', 'muiformlabel')
# ('muiformlabel', 'root')
# ('root', 'mui')
# ('mui', 'disabled')
# ('disabled', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '38')
# ('38', 'muiformlabel')
# ('muiformlabel', 'root')
# ('root', 'mui')
# ('mui', 'error')
# ('error', 'color')
# ('color', 'f44336')
# ('f44336', 'muiformlabel')
# ('muiformlabel', 'asterisk')
# ('asterisk', 'mui')
# ('mui', 'error')
# ('error', 'color')
# ('color', 'f44336')
# ('f44336', 'muiinputlabel')
# ('muiinputlabel', 'root')
# ('root', 'display')
# ('display', 'block')
# ('block', 'transform')
# ('transform', 'origin')
# ('origin', 'top')
# ('top', 'left')
# ('left', 'muiinputlabel')
# ('muiinputlabel', 'formcontrol')
# ('formcontrol', 'top')
# ('top', '0')
# ('0', 'left')
# ('left', '0')
# ('0', 'position')
# ('position', 'absolute')
# ('absolute', 'transform')
# ('transform', 'translate')
# ('translate', '0')
# ('0', '24px')
# ('24px', 'scale')
# ('scale', '1')
# ('1', 'muiinputlabel')
# ('muiinputlabel', 'margindense')
# ('margindense', 'transform')
# ('transform', 'translate')
# ('translate', '0')
# ('0', '21px')
# ('21px', 'scale')
# ('scale', '1')
# ('1', 'muiinputlabel')
# ('muiinputlabel', 'shrink')
# ('shrink', 'transform')
# ('transform', 'translate')
# ('translate', '0')
# ('0', '1')
# ('1', '5px')
# ('5px', 'scale')
# ('scale', '0')
# ('0', '75')
# ('75', 'transform')
# ('transform', 'origin')
# ('origin', 'top')
# ('top', 'left')
# ('left', 'muiinputlabel')
# ('muiinputlabel', 'animated')
# ('animated', 'transition')
# ('transition', 'color')
# ('color', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'transform')
# ('transform', '200ms')
# ('200ms', 'cubic')
# ('cubic', 'bezier')
# ('bezier', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '2')
# ('2', '1')
# ('1', '0ms')
# ('0ms', 'muiinputlabel')
# ('muiinputlabel', 'filled')
# ('filled', 'z')
# ('z', 'index')
# ('index', '1')
# ('1', 'transform')
# ('transform', 'translate')
# ('translate', '12px')
# ('12px', '20px')
# ('20px', 'scale')
# ('scale', '1')
# ('1', 'pointer')
# ('pointer', 'events')
# ('events', 'none')
# ('none', 'muiinputlabel')
# ('muiinputlabel', 'filled')
# ('filled', 'muiinputlabel')
# ('muiinputlabel', 'margindense')
# ('margindense', 'transform')
# ('transform', 'translate')
# ('translate', '12px')
# ('12px', '17px')
# ('17px', 'scale')
# ('scale', '1')
# ('1', 'muiinputlabel')
# ('muiinputlabel', 'filled')
# ('filled', 'muiinputlabel')
# ('muiinputlabel', 'shrink')
# ('shrink', 'transform')
# ('transform', 'translate')
# ('translate', '12px')
# ('12px', '10px')
# ('10px', 'scale')
# ('scale', '0')
# ('0', '75')
# ('75', 'muiinputlabel')
# ('muiinputlabel', 'filled')
# ('filled', 'muiinputlabel')
# ('muiinputlabel', 'shrink')
# ('shrink', 'muiinputlabel')
# ('muiinputlabel', 'margindense')
# ('margindense', 'transform')
# ('transform', 'translate')
# ('translate', '12px')
# ('12px', '7px')
# ('7px', 'scale')
# ('scale', '0')
# ('0', '75')
# ('75', 'muiinputlabel')
# ('muiinputlabel', 'outlined')
# ('outlined', 'z')
# ('z', 'index')
# ('index', '1')
# ('1', 'transform')
# ('transform', 'translate')
# ('translate', '14px')
# ('14px', '20px')
# ('20px', 'scale')
# ('scale', '1')
# ('1', 'pointer')
# ('pointer', 'events')
# ('events', 'none')
# ('none', 'muiinputlabel')
# ('muiinputlabel', 'outlined')
# ('outlined', 'muiinputlabel')
# ('muiinputlabel', 'margindense')
# ('margindense', 'transform')
# ('transform', 'translate')
# ('translate', '14px')
# ('14px', '12px')
# ('12px', 'scale')
# ('scale', '1')
# ('1', 'muiinputlabel')
# ('muiinputlabel', 'outlined')
# ('outlined', 'muiinputlabel')
# ('muiinputlabel', 'shrink')
# ('shrink', 'transform')
# ('transform', 'translate')
# ('translate', '14px')
# ('14px', '6px')
# ('6px', 'scale')
# ('scale', '0')
# ('0', '75')
# ('75', 'muiformcontrol')
# ('muiformcontrol', 'root')
# ('root', 'border')
# ('border', '0')
# ('0', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'inline')
# ('inline', 'flex')
# ('flex', 'padding')
# ('padding', '0')
# ('0', 'position')
# ('position', 'relative')
# ('relative', 'min')
# ('min', 'width')
# ('width', '0')
# ('0', 'flex')
# ('flex', 'direction')
# ('direction', 'column')
# ('column', 'vertical')
# ('vertical', 'align')
# ('align', 'top')
# ('top', 'muiformcontrol')
# ('muiformcontrol', 'marginnormal')
# ('marginnormal', 'margin')
# ('margin', 'top')
# ('top', '16px')
# ('16px', 'margin')
# ('margin', 'bottom')
# ('bottom', '8px')
# ('8px', 'muiformcontrol')
# ('muiformcontrol', 'margindense')
# ('margindense', 'margin')
# ('margin', 'top')
# ('top', '8px')
# ('8px', 'margin')
# ('margin', 'bottom')
# ('bottom', '4px')
# ('4px', 'muiformcontrol')
# ('muiformcontrol', 'fullwidth')
# ('fullwidth', 'width')
# ('width', '100')
# ('100', 'muimenu')
# ('muimenu', 'paper')
# ('paper', 'max')
# ('max', 'height')
# ('height', 'calc')
# ('calc', '100')
# ('100', '96px')
# ('96px', 'webkit')
# ('webkit', 'overflow')
# ('overflow', 'scrolling')
# ('scrolling', 'touch')
# ('touch', 'muimenu')
# ('muimenu', 'list')
# ('list', 'outline')
# ('outline', '0')
# ('0', 'muiselect')
# ('muiselect', 'select')
# ('select', 'cursor')
# ('cursor', 'pointer')
# ('pointer', 'min')
# ('min', 'width')
# ('width', '16px')
# ('16px', 'user')
# ('user', 'select')
# ('select', 'none')
# ('none', 'border')
# ('border', 'radius')
# ('radius', '0')
# ('0', 'moz')
# ('moz', 'appearance')
# ('appearance', 'none')
# ('none', 'webkit')
# ('webkit', 'appearance')
# ('appearance', 'none')
# ('none', 'muiselect')
# ('muiselect', 'select')
# ('select', 'focus')
# ('focus', 'border')
# ('border', 'radius')
# ('radius', '0')
# ('0', 'background')
# ('background', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '05')
# ('05', 'muiselect')
# ('muiselect', 'select')
# ('select', 'ms')
# ('ms', 'expand')
# ('expand', 'display')
# ('display', 'none')
# ('none', 'muiselect')
# ('muiselect', 'select')
# ('select', 'mui')
# ('mui', 'disabled')
# ('disabled', 'cursor')
# ('cursor', 'default')
# ('default', 'muiselect')
# ('muiselect', 'select')
# ('select', 'multiple')
# ('multiple', 'height')
# ('height', 'auto')
# ('auto', 'muiselect')
# ('muiselect', 'select')
# ('select', 'not')
# ('not', 'multiple')
# ('multiple', 'option')
# ('option', 'muiselect')
# ('muiselect', 'select')
# ('select', 'not')
# ('not', 'multiple')
# ('multiple', 'optgroup')
# ('optgroup', 'background')
# ('background', 'color')
# ('color', 'fff')
# ('fff', 'muiselect')
# ('muiselect', 'outlined')
# ('outlined', 'border')
# ('border', 'radius')
# ('radius', '4px')
# ('4px', 'muiselect')
# ('muiselect', 'selectmenu')
# ('selectmenu', 'height')
# ('height', 'auto')
# ('auto', 'overflow')
# ('overflow', 'hidden')
# ('hidden', 'white')
# ('white', 'space')
# ('space', 'nowrap')
# ('nowrap', 'text')
# ('text', 'overflow')
# ('overflow', 'ellipsis')
# ('ellipsis', 'muiselect')
# ('muiselect', 'icon')
# ('icon', 'top')
# ('top', 'calc')
# ('calc', '50')
# ('50', '12px')
# ('12px', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '54')
# ('54', 'right')
# ('right', '0')
# ('0', 'position')
# ('position', 'absolute')
# ('absolute', 'pointer')
# ('pointer', 'events')
# ('events', 'none')
# ('none', 'html')
# ('html', 'box')
# ('box', 'sizing')
# ('sizing', 'border')
# ('border', 'box')
# ('box', 'webkit')
# ('webkit', 'font')
# ('font', 'smoothing')
# ('smoothing', 'antialiased')
# ('antialiased', 'moz')
# ('moz', 'osx')
# ('osx', 'font')
# ('font', 'smoothing')
# ('smoothing', 'grayscale')
# ('grayscale', 'before')
# ('before', 'after')
# ('after', 'box')
# ('box', 'sizing')
# ('sizing', 'inherit')
# ('inherit', 'strong')
# ('strong', 'b')
# ('b', 'font')
# ('font', 'weight')
# ('weight', 'bolder')
# ('bolder', 'body')
# ('body', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '87')
# ('87', 'margin')
# ('margin', '0')
# ('0', 'font')
# ('font', 'size')
# ('size', '0')
# ('0', '875rem')
# ('875rem', 'font')
# ('font', 'family')
# ('family', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '400')
# ('400', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '43')
# ('43', 'letter')
# ('letter', 'spacing')
# ('spacing', '0')
# ('0', '01071em')
# ('01071em', 'background')
# ('background', 'color')
# ('color', 'fafafa')
# ('fafafa', 'media')
# ('media', 'print')
# ('print', 'body')
# ('body', 'background')
# ('background', 'color')
# ('color', 'fff')
# ('fff', 'body')
# ('body', 'backdrop')
# ('backdrop', 'background')
# ('background', 'color')
# ('color', 'fafafa')
# ('fafafa', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss316')
# ('jss316', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '52px')
# ('52px', '32px')
# ('32px', 'border')
# ('border', 'top')
# ('top', '3px')
# ('3px', 'solid')
# ('solid', '5500ff')
# ('5500ff', 'box')
# ('box', 'sizing')
# ('sizing', 'border')
# ('border', 'box')
# ('box', 'jss316')
# ('jss316', 'box')
# ('box', 'sizing')
# ('sizing', 'border')
# ('border', 'box')
# ('box', 'jss317')
# ('jss317', 'width')
# ('width', '100')
# ('100', 'margin')
# ('margin', 'auto')
# ('auto', 'display')
# ('display', 'flex')
# ('flex', 'max')
# ('max', 'width')
# ('width', '1024px')
# ('1024px', 'flex')
# ('flex', 'direction')
# ('direction', 'column')
# ('column', 'jss318')
# ('jss318', 'max')
# ('max', 'width')
# ('width', '35px')
# ('35px', 'jss319')
# ('jss319', 'display')
# ('display', 'flex')
# ('flex', 'justify')
# ('justify', 'items')
# ('items', 'space')
# ('space', 'bettween')
# ('bettween', 'flex')
# ('flex', 'direction')
# ('direction', 'column')
# ('column', 'jss320')
# ('jss320', 'color')
# ('color', '50f')
# ('50f', 'word')
# ('word', 'wrap')
# ('wrap', 'breakword')
# ('breakword', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '25')
# ('25', 'text')
# ('text', 'transform')
# ('transform', 'uppercase')
# ('uppercase', 'jss321')
# ('jss321', 'color')
# ('color', '333')
# ('333', 'margin')
# ('margin', '0')
# ('0', 'padding')
# ('padding', '0')
# ('0', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'jss321')
# ('jss321', 'li')
# ('li', 'color')
# ('color', '333')
# ('333', 'margin')
# ('margin', '1px')
# ('1px', '0')
# ('0', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '10px')
# ('10px', '0')
# ('0', 'font')
# ('font', 'size')
# ('size', '15px')
# ('15px', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '33')
# ('33', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss321')
# ('jss321', 'li')
# ('li', 'span')
# ('span', 'color')
# ('color', '000')
# ('000', 'display')
# ('display', 'block')
# ('block', 'jss322')
# ('jss322', 'height')
# ('height', '1px')
# ('1px', 'margin')
# ('margin', '30px')
# ('30px', '0')
# ('0', '15px')
# ('15px', 'border')
# ('border', 'top')
# ('top', '1px')
# ('1px', 'solid')
# ('solid', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '0')
# ('0', '08')
# ('08', 'jss323')
# ('jss323', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '16px')
# ('16px', '0px')
# ('0px', '32px')
# ('32px', '0px')
# ('0px', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'flex')
# ('flex', 'direction')
# ('direction', 'column')
# ('column', 'justify')
# ('justify', 'content')
# ('content', 'flex')
# ('flex', 'start')
# ('start', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'jss323')
# ('jss323', 'li')
# ('li', 'color')
# ('color', '666')
# ('666', 'margin')
# ('margin', 'right')
# ('right', '30px')
# ('30px', 'margin')
# ('margin', 'bottom')
# ('bottom', '16px')
# ('16px', 'jss323')
# ('jss323', 'li')
# ('li', 'color')
# ('color', '666')
# ('666', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss324')
# ('jss324', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '16px')
# ('16px', '0px')
# ('0px', '0px')
# ('0px', '0px')
# ('0px', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'justify')
# ('justify', 'content')
# ('content', 'flex')
# ('flex', 'start')
# ('start', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'jss324')
# ('jss324', 'li')
# ('li', 'margin')
# ('margin', 'right')
# ('right', '16px')
# ('16px', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss319')
# ('jss319', 'width')
# ('width', '100')
# ('100', 'display')
# ('display', 'flex')
# ('flex', 'flex')
# ('flex', 'flow')
# ('flow', 'row')
# ('row', 'wrap')
# ('wrap', 'jss319')
# ('jss319', 'div')
# ('div', 'flex')
# ('flex', '1')
# ('1', 'jss321')
# ('jss321', 'color')
# ('color', '333')
# ('333', 'margin')
# ('margin', '0')
# ('0', 'padding')
# ('padding', '0')
# ('0', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'jss321')
# ('jss321', 'li')
# ('li', 'color')
# ('color', '333')
# ('333', 'margin')
# ('margin', '1px')
# ('1px', '0')
# ('0', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '5px')
# ('5px', '0')
# ('0', 'font')
# ('font', 'size')
# ('size', '15px')
# ('15px', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '33')
# ('33', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss321')
# ('jss321', 'li')
# ('li', 'span')
# ('span', 'color')
# ('color', '000')
# ('000', 'display')
# ('display', 'block')
# ('block', 'jss325')
# ('jss325', 'width')
# ('width', '100')
# ('100', 'display')
# ('display', 'flex')
# ('flex', 'flex')
# ('flex', 'wrap')
# ('wrap', 'nowrap')
# ('nowrap', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'justify')
# ('justify', 'content')
# ('content', 'space')
# ('space', 'between')
# ('between', 'jss323')
# ('jss323', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '16px')
# ('16px', '0px')
# ('0px', '0px')
# ('0px', '0px')
# ('0px', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'justify')
# ('justify', 'content')
# ('content', 'flex')
# ('flex', 'start')
# ('start', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'jss323')
# ('jss323', 'li')
# ('li', 'margin')
# ('margin', 'bottom')
# ('bottom', '0px')
# ('0px', 'jss324')
# ('jss324', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '16px')
# ('16px', '0px')
# ('0px', '0px')
# ('0px', '0px')
# ('0px', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'justify')
# ('justify', 'content')
# ('content', 'flex')
# ('flex', 'start')
# ('start', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'jss324')
# ('jss324', 'li')
# ('li', 'margin')
# ('margin', 'left')
# ('left', '16px')
# ('16px', 'margin')
# ('margin', 'right')
# ('right', '0px')
# ('0px', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss149')
# ('jss149', 'color')
# ('color', 'fff')
# ('fff', 'margin')
# ('margin', '10px')
# ('10px', '0px')
# ('0px', '16px')
# ('16px', '0px')
# ('0px', 'font')
# ('font', 'size')
# ('size', '2')
# ('2', '5em')
# ('5em', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'line')
# ('line', 'height')
# ('height', 'normal')
# ('normal', 'text')
# ('text', 'transform')
# ('transform', 'initial')
# ('initial', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss149')
# ('jss149', 'font')
# ('font', 'size')
# ('size', '4')
# ('4', '1em')
# ('1em', 'max')
# ('max', 'width')
# ('width', '618px')
# ('618px', 'font')
# ('font', 'weight')
# ('weight', '600')
# ('600', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss150')
# ('jss150', 'color')
# ('color', 'fff')
# ('fff', 'margin')
# ('margin', '0px')
# ('0px', '0px')
# ('0px', '24px')
# ('24px', '0px')
# ('0px', 'font')
# ('font', 'size')
# ('size', '1')
# ('1', '2em')
# ('2em', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', 'normal')
# ('normal', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss150')
# ('jss150', 'max')
# ('max', 'width')
# ('width', '624px')
# ('624px', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss133')
# ('jss133', 'width')
# ('width', '35px')
# ('35px', 'display')
# ('display', 'block')
# ('block', 'jss134')
# ('jss134', 'display')
# ('display', 'none')
# ('none', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss133')
# ('jss133', 'display')
# ('display', 'none')
# ('none', 'jss134')
# ('jss134', 'display')
# ('display', 'block')
# ('block', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss106')
# ('jss106', 'display')
# ('display', 'flex')
# ('flex', 'margin')
# ('margin', 'bottom')
# ('bottom', '92px')
# ('92px', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'justify')
# ('justify', 'content')
# ('content', 'space')
# ('space', 'between')
# ('between', 'jss107')
# ('jss107', 'display')
# ('display', 'flex')
# ('flex', 'margin')
# ('margin', 'bottom')
# ('bottom', '0px')
# ('0px', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'justify')
# ('justify', 'content')
# ('content', 'space')
# ('space', 'between')
# ('between', 'jss107')
# ('jss107', 'color')
# ('color', '333')
# ('333', 'jss108')
# ('jss108', 'height')
# ('height', '50px')
# ('50px', 'max')
# ('max', 'width')
# ('width', '150px')
# ('150px', 'margin')
# ('margin', 'top')
# ('top', '24px')
# ('24px', 'margin')
# ('margin', 'bottom')
# ('bottom', '10px')
# ('10px', 'padding')
# ('padding', 'bottom')
# ('bottom', '24px')
# ('24px', 'jss109')
# ('jss109', 'flex')
# ('flex', '1')
# ('1', 'display')
# ('display', 'flex')
# ('flex', 'position')
# ('position', 'relative')
# ('relative', 'flex')
# ('flex', 'flow')
# ('flow', 'row')
# ('row', 'nowrap')
# ('nowrap', 'margin')
# ('margin', 'bottom')
# ('bottom', '0')
# ('0', 'justify')
# ('justify', 'content')
# ('content', 'flex')
# ('flex', 'end')
# ('end', 'jss110')
# ('jss110', 'color')
# ('color', 'fff')
# ('fff', 'position')
# ('position', 'absolute')
# ('absolute', 'jss111')
# ('jss111', 'display')
# ('display', 'none')
# ('none', 'jss112')
# ('jss112', 'cursor')
# ('cursor', 'pointer')
# ('pointer', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'padding')
# ('padding', '0px')
# ('0px', '16px')
# ('16px', '0px')
# ('0px', '0px')
# ('0px', 'jss112')
# ('jss112', 'hover')
# ('hover', 'listonoff')
# ('listonoff', 'display')
# ('display', 'block')
# ('block', 'jss113')
# ('jss113', 'width')
# ('width', '100')
# ('100', 'height')
# ('height', '16px')
# ('16px', 'padding')
# ('padding', '16px')
# ('16px', 'jss114')
# ('jss114', 'top')
# ('top', '0')
# ('0', 'left')
# ('left', '0')
# ('0', 'width')
# ('width', '100vw')
# ('100vw', 'height')
# ('height', '100vh')
# ('100vh', 'display')
# ('display', 'block')
# ('block', 'z')
# ('z', 'index')
# ('index', '8')
# ('8', 'position')
# ('position', 'fixed')
# ('fixed', 'background')
# ('background', 'color')
# ('color', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '5')
# ('5', 'jss115')
# ('jss115', 'top')
# ('top', '0')
# ('0', 'left')
# ('left', '0')
# ('0', 'height')
# ('height', '100vh')
# ('100vh', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '0')
# ('0', 'z')
# ('z', 'index')
# ('index', '9')
# ('9', 'position')
# ('position', 'fixed')
# ('fixed', 'min')
# ('min', 'width')
# ('width', '260px')
# ('260px', 'box')
# ('box', 'shadow')
# ('shadow', '0px')
# ('0px', '0px')
# ('0px', '10px')
# ('10px', '333')
# ('333', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'border')
# ('border', 'right')
# ('right', '1px')
# ('1px', 'solid')
# ('solid', 'rgba')
# ('rgba', '0')
# ('0', '0')
# ('0', '0')
# ('0', '1')
# ('1', 'flex')
# ('flex', 'direction')
# ('direction', 'column')
# ('column', 'list')
# ('list', 'style')
# ('style', 'type')
# ('type', 'none')
# ('none', 'background')
# ('background', 'color')
# ('color', 'fff')
# ('fff', 'jss115')
# ('jss115', 'li')
# ('li', 'margin')
# ('margin', '0')
# ('0', 'padding')
# ('padding', '0')
# ('0', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'jss115')
# ('jss115', 'li')
# ('li', 'color')
# ('color', '000')
# ('000', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '4px')
# ('4px', '15px')
# ('15px', 'font')
# ('font', 'size')
# ('size', '16px')
# ('16px', 'border')
# ('border', 'left')
# ('left', '5px')
# ('5px', 'solid')
# ('solid', 'transparent')
# ('transparent', 'line')
# ('line', 'height')
# ('height', '46px')
# ('46px', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss116')
# ('jss116', 'display')
# ('display', 'none')
# ('none', 'jss117')
# ('jss117', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss118')
# ('jss118', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss119')
# ('jss119', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss120')
# ('jss120', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss121')
# ('jss121', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss122')
# ('jss122', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss123')
# ('jss123', 'loginbtn')
# ('loginbtn', 'display')
# ('display', 'none')
# ('none', 'jss124')
# ('jss124', 'display')
# ('display', 'block')
# ('block', 'jss125')
# ('jss125', 'display')
# ('display', 'none')
# ('none', 'jss126')
# ('jss126', 'hover')
# ('hover', 'border')
# ('border', 'left')
# ('left', '5px')
# ('5px', 'solid')
# ('solid', '24a9ff')
# ('24a9ff', 'jss127')
# ('jss127', 'hover')
# ('hover', 'border')
# ('border', 'left')
# ('left', '5px')
# ('5px', 'solid')
# ('solid', '5dd0f0')
# ('5dd0f0', 'jss128')
# ('jss128', 'hover')
# ('hover', 'border')
# ('border', 'left')
# ('left', '5px')
# ('5px', 'solid')
# ('solid', '83c341')
# ('83c341', 'jss129')
# ('jss129', 'hover')
# ('hover', 'border')
# ('border', 'left')
# ('left', '5px')
# ('5px', 'solid')
# ('solid', 'ff4a6e')
# ('ff4a6e', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss124')
# ('jss124', 'display')
# ('display', 'none')
# ('none', 'jss125')
# ('jss125', 'display')
# ('display', 'block')
# ('block', 'jss116')
# ('jss116', 'top')
# ('top', '46px')
# ('46px', 'right')
# ('right', '16px')
# ('16px', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '5px')
# ('5px', '0px')
# ('0px', 'z')
# ('z', 'index')
# ('index', '2')
# ('2', 'position')
# ('position', 'absolute')
# ('absolute', 'min')
# ('min', 'width')
# ('width', '240px')
# ('240px', 'box')
# ('box', 'shadow')
# ('shadow', '0px')
# ('0px', '0px')
# ('0px', '5px')
# ('5px', '333')
# ('333', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'border')
# ('border', 'radius')
# ('radius', '4px')
# ('4px', 'background')
# ('background', 'color')
# ('color', 'fff')
# ('fff', 'jss116')
# ('jss116', 'li')
# ('li', 'margin')
# ('margin', '0')
# ('0', 'padding')
# ('padding', '0')
# ('0', 'list')
# ('list', 'style')
# ('style', 'none')
# ('none', 'jss116')
# ('jss116', 'li')
# ('li', 'color')
# ('color', '000')
# ('000', 'display')
# ('display', 'block')
# ('block', 'padding')
# ('padding', '8px')
# ('8px', '20px')
# ('20px', '8px')
# ('8px', '14px')
# ('14px', 'font')
# ('font', 'size')
# ('size', '16px')
# ('16px', 'border')
# ('border', 'left')
# ('left', '5px')
# ('5px', 'solid')
# ('solid', 'transparent')
# ('transparent', 'line')
# ('line', 'height')
# ('height', '30px')
# ('30px', 'text')
# ('text', 'transform')
# ('transform', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'arial')
# ('arial', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss130')
# ('jss130', 'color')
# ('color', 'fff')
# ('fff', 'cursor')
# ('cursor', 'pointer')
# ('pointer', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'padding')
# ('padding', '9px')
# ('9px', '20px')
# ('20px', 'position')
# ('position', 'relative')
# ('relative', 'font')
# ('font', 'size')
# ('size', '16px')
# ('16px', 'text')
# ('text', 'align')
# ('align', 'center')
# ('center', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'border')
# ('border', 'radius')
# ('radius', '2px')
# ('2px', 'margin')
# ('margin', 'bottom')
# ('bottom', '6px')
# ('6px', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss130')
# ('jss130', 'hover')
# ('hover', 'background')
# ('background', 'color')
# ('color', 'rgba')
# ('rgba', '255')
# ('255', '255')
# ('255', '255')
# ('255', '1')
# ('1', 'jss130')
# ('jss130', 'svg')
# ('svg', 'top')
# ('top', '1px')
# ('1px', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'position')
# ('position', 'relative')
# ('relative', 'font')
# ('font', 'size')
# ('size', '24px')
# ('24px', 'margin')
# ('margin', 'left')
# ('left', '5px')
# ('5px', 'vertical')
# ('vertical', 'align')
# ('align', 'top')
# ('top', 'jss130')
# ('jss130', 'span')
# ('span', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'vertical')
# ('vertical', 'align')
# ('align', 'middle')
# ('middle', 'jss131')
# ('jss131', 'color')
# ('color', '333')
# ('333', 'cursor')
# ('cursor', 'pointer')
# ('pointer', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'padding')
# ('padding', '9px')
# ('9px', '20px')
# ('20px', 'position')
# ('position', 'relative')
# ('relative', 'font')
# ('font', 'size')
# ('size', '16px')
# ('16px', 'text')
# ('text', 'align')
# ('align', 'center')
# ('center', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'border')
# ('border', 'radius')
# ('radius', '2px')
# ('2px', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss131')
# ('jss131', 'hover')
# ('hover', 'background')
# ('background', 'color')
# ('color', 'rgba')
# ('rgba', '51')
# ('51', '51')
# ('51', '51')
# ('51', '1')
# ('1', 'jss131')
# ('jss131', 'svg')
# ('svg', 'top')
# ('top', '4px')
# ('4px', 'position')
# ('position', 'relative')
# ('relative', 'font')
# ('font', 'size')
# ('size', '18px')
# ('18px', 'jss132')
# ('jss132', 'border')
# ('border', '2px')
# ('2px', 'solid')
# ('solid', 'rgb')
# ('rgb', '255')
# ('255', '255')
# ('255', '255')
# ('255', 'border')
# ('border', 'radius')
# ('radius', '4px')
# ('4px', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss151')
# ('jss151', 'color')
# ('color', 'fff')
# ('fff', 'width')
# ('width', '100')
# ('100', 'border')
# ('border', '0')
# ('0', 'cursor')
# ('cursor', 'pointer')
# ('pointer', 'padding')
# ('padding', '15px')
# ('15px', '30px')
# ('30px', 'font')
# ('font', 'size')
# ('size', '16px')
# ('16px', 'margin')
# ('margin', 'top')
# ('top', '0')
# ('0', 'text')
# ('text', 'align')
# ('align', 'center')
# ('center', 'transition')
# ('transition', 'all')
# ('all', '0')
# ('0', '1s')
# ('1s', 'ease')
# ('ease', 'in')
# ('in', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'margin')
# ('margin', 'right')
# ('right', '0px')
# ('0px', 'border')
# ('border', 'radius')
# ('radius', '2px')
# ('2px', 'margin')
# ('margin', 'bottom')
# ('bottom', '16px')
# ('16px', 'text')
# ('text', 'transform')
# ('transform', 'uppercase')
# ('uppercase', 'text')
# ('text', 'decoration')
# ('decoration', 'none')
# ('none', 'jss152')
# ('jss152', 'background')
# ('background', 'color')
# ('color', '24a9ff')
# ('24a9ff', 'jss153')
# ('jss153', 'background')
# ('background', 'color')
# ('color', '5dd0f0')
# ('5dd0f0', 'jss154')
# ('jss154', 'background')
# ('background', 'color')
# ('color', '83c341')
# ('83c341', 'jss155')
# ('jss155', 'background')
# ('background', 'color')
# ('color', 'ff4a6e')
# ('ff4a6e', 'jss156')
# ('jss156', 'background')
# ('background', 'color')
# ('color', '5500ff')
# ('5500ff', 'jss157')
# ('jss157', 'width')
# ('width', '100')
# ('100', 'display')
# ('display', 'block')
# ('block', 'background')
# ('background', 'color')
# ('color', '5500ff')
# ('5500ff', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss151')
# ('jss151', 'width')
# ('width', 'auto')
# ('auto', 'margin')
# ('margin', 'right')
# ('right', '16px')
# ('16px', 'jss151')
# ('jss151', 'hover')
# ('hover', 'transform')
# ('transform', 'scale')
# ('scale', '1')
# ('1', '035')
# ('035', 'jss156')
# ('jss156', 'margin')
# ('margin', '0px')
# ('0px', '0px')
# ('0px', '16px')
# ('16px', '0px')
# ('0px', 'background')
# ('background', 'color')
# ('color', '5500ff')
# ('5500ff', 'jss157')
# ('jss157', 'margin')
# ('margin', 'auto')
# ('auto', 'display')
# ('display', 'block')
# ('block', 'background')
# ('background', 'color')
# ('color', '5500ff')
# ('5500ff', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss144')
# ('jss144', 'color')
# ('color', 'fff')
# ('fff', 'margin')
# ('margin', 'auto')
# ('auto', 'display')
# ('display', 'inline')
# ('inline', 'block')
# ('block', 'padding')
# ('padding', '5px')
# ('5px', '10px')
# ('10px', 'text')
# ('text', 'align')
# ('align', 'left')
# ('left', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '25')
# ('25', 'border')
# ('border', 'radius')
# ('radius', '2px')
# ('2px', 'text')
# ('text', 'transform')
# ('transform', 'uppercase')
# ('uppercase', 'jss145')
# ('jss145', 'background')
# ('background', 'color')
# ('color', '24a9ff')
# ('24a9ff', 'jss146')
# ('jss146', 'background')
# ('background', 'color')
# ('color', '5dd0f0')
# ('5dd0f0', 'jss147')
# ('jss147', 'background')
# ('background', 'color')
# ('color', '83c341')
# ('83c341', 'jss148')
# ('jss148', 'background')
# ('background', 'color')
# ('color', 'ff4a6e')
# ('ff4a6e', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss159')
# ('jss159', 'img')
# ('img', 'height')
# ('height', '30px')
# ('30px', 'margin')
# ('margin', '0')
# ('0', 'display')
# ('display', 'block')
# ('block', 'opacity')
# ('opacity', '8')
# ('8', 'max')
# ('max', 'width')
# ('width', '80vw')
# ('80vw', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss158')
# ('jss158', 'color')
# ('color', 'fff')
# ('fff', 'display')
# ('display', 'block')
# ('block', 'opacity')
# ('opacity', '1')
# ('1', 'font')
# ('font', 'size')
# ('size', '1')
# ('1', '17em')
# ('17em', 'margin')
# ('margin', 'top')
# ('top', '46px')
# ('46px', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'line')
# ('line', 'height')
# ('height', '1')
# ('1', '25')
# ('25', 'text')
# ('text', 'transform')
# ('transform', 'uppercase')
# ('uppercase', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss177')
# ('jss177', 'margin')
# ('margin', '16px')
# ('16px', '0px')
# ('0px', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '0px')
# ('0px', 'flex')
# ('flex', 'wrap')
# ('wrap', 'nowrap')
# ('nowrap', 'max')
# ('max', 'width')
# ('width', '300px')
# ('300px', 'align')
# ('align', 'self')
# ('self', 'flex')
# ('flex', 'start')
# ('start', 'align')
# ('align', 'items')
# ('items', 'center')
# ('center', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'jss178')
# ('jss178', 'color')
# ('color', 'rgba')
# ('rgba', '15')
# ('15', '32')
# ('32', '48')
# ('48', '0')
# ('0', '6')
# ('6', 'display')
# ('display', 'block')
# ('block', 'font')
# ('font', 'size')
# ('size', '1')
# ('1', '1em')
# ('1em', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'jss179')
# ('jss179', 'color')
# ('color', 'rgba')
# ('rgba', '15')
# ('15', '32')
# ('32', '48')
# ('48', '0')
# ('0', '4')
# ('4', 'font')
# ('font', 'size')
# ('size', '1em')
# ('1em', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'jss180')
# ('jss180', 'min')
# ('min', 'width')
# ('width', '68px')
# ('68px', 'margin')
# ('margin', 'right')
# ('right', '20px')
# ('20px', 'jss181')
# ('jss181', 'g')
# ('g', 'fill')
# ('fill', '24a9ff')
# ('24a9ff', 'jss182')
# ('jss182', 'g')
# ('g', 'fill')
# ('fill', '5dd0f0')
# ('5dd0f0', 'jss183')
# ('jss183', 'g')
# ('g', 'fill')
# ('fill', '83c341')
# ('83c341', 'jss184')
# ('jss184', 'g')
# ('g', 'fill')
# ('fill', 'ff4a6e')
# ('ff4a6e', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss177')
# ('jss177', 'margin')
# ('margin', 'auto')
# ('auto', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '20px')
# ('20px', 'flex')
# ('flex', 'wrap')
# ('wrap', 'nowrap')
# ('nowrap', 'max')
# ('max', 'width')
# ('width', '300px')
# ('300px', 'align')
# ('align', 'self')
# ('self', 'flex')
# ('flex', 'start')
# ('start', 'align')
# ('align', 'items')
# ('items', 'center')
# ('center', 'flex')
# ('flex', 'direction')
# ('direction', 'row')
# ('row', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '0px')
# ('0px', 'jss203')
# ('jss203', 'margin')
# ('margin', '32px')
# ('32px', 'auto')
# ('auto', '0px')
# ('0px', 'auto')
# ('auto', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '0px')
# ('0px', 'max')
# ('max', 'width')
# ('width', '360px')
# ('360px', 'align')
# ('align', 'self')
# ('self', 'flex')
# ('flex', 'start')
# ('start', 'align')
# ('align', 'items')
# ('items', 'flex')
# ('flex', 'start')
# ('start', 'flex')
# ('flex', 'direction')
# ('direction', 'column')
# ('column', 'jss203')
# ('jss203', 'img')
# ('img', 'width')
# ('width', '50px')
# ('50px', 'max')
# ('max', 'width')
# ('width', '50px')
# ('50px', 'margin')
# ('margin', 'bottom')
# ('bottom', '8px')
# ('8px', 'jss204')
# ('jss204', 'color')
# ('color', '444444')
# ('444444', 'margin')
# ('margin', '0')
# ('0', '0')
# ('0', '5px')
# ('5px', 'font')
# ('font', 'size')
# ('size', '1')
# ('1', '1em')
# ('1em', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'font')
# ('font', 'weight')
# ('weight', '500')
# ('500', 'text')
# ('text', 'transform')
# ('transform', 'uppercase')
# ('uppercase', 'jss205')
# ('jss205', 'color')
# ('color', '000000')
# ('000000', 'font')
# ('font', 'size')
# ('size', '1em')
# ('1em', 'font')
# ('font', 'family')
# ('family', 'rubik')
# ('rubik', 'roboto')
# ('roboto', 'helvetica')
# ('helvetica', 'arial')
# ('arial', 'sans')
# ('sans', 'serif')
# ('serif', 'media')
# ('media', 'min')
# ('min', 'width')
# ('width', '960px')
# ('960px', 'jss203')
# ('jss203', 'margin')
# ('margin', '0px')
# ('0px', 'display')
# ('display', 'flex')
# ('flex', 'padding')
# ('padding', '20px')
# ('20px', 'max')
# ('max', 'width')
# ('width', '360px')
# ('360px', 'align')
# ('align', 'self')
# ('self', 'flex')
# ('flex', 'start')
# ...
# ('jpg', 'auto')
# ('auto', 'compress')
# ('compress', 'format')
# ('format', 'key_title')
# ('key_title', '1')
# ('1', 'title')
# ('title', 'predicción')
# ('predicción', 'inteligente')
# ('inteligente', 'precios')
# ('precios', 'inmuebles')
# ('inmuebles', 'subtitle')
# ('subtitle', 'realizara')
# ('realizara', 's')
# ('s', 'exploracio')
# ('exploracio', 'n')
# ('n', 'visualizacio')
# ('visualizacio', 'n')
# ('n', 'datos')
# ('datos', 'luego')
# ('luego', 'crear')
# ('crear', 'modelo')
# ('modelo', 'inteligencia')
# ('inteligencia', 'artificial')
# ('artificial', 'prediga')
# ('prediga', 'automa')
# ('automa', 'ticamente')
# ('ticamente', 'costo')
# ('costo', 'inmuebles')
# ('inmuebles', 'barrio')
# ('barrio', 'aprendera')
# ('aprendera', 's')
# ('s', 'algoritmos')
# ('algoritmos', 'regresio')
# ('regresio', 'n')
# ('n', 'lineal')
# ('lineal', 'usando')
# ('usando', 'dataset')
# ('dataset', 'real')
# ('real', 'start')
# ('start', 'up')
# ('up', 'properati')
# ('properati', 'img')
# ('img', 'dimensions')
# ('dimensions', 'width')
# ('width', '1000')
# ('1000', 'height')
# ('height', '500')
# ('500', 'alt')
# ('alt', 'null')
# ('null', 'copyright')
# ('copyright', 'null')
# ('null', 'url')
# ('url', 'https')
# ('https', 'images')
# ('images', 'prismic')
# ('prismic', 'io')
# ('io', 'acamica')
# ('acamica', '2e345adde52acba6022d0b76d6ae7986151ba63a_2')
# ('2e345adde52acba6022d0b76d6ae7986151ba63a_2', 'jpg')
# ('jpg', 'auto')
# ('auto', 'compress')
# ('compress', 'format')
# ('format', 'key_title')
# ('key_title', '2')
# ('2', 'title')
# ('title', 'análisis')
# ('análisis', 'sentimientos')
# ('sentimientos', 'texto')
# ('texto', 'subtitle')
# ('subtitle', 'construira')
# ('construira', 's')
# ('s', 'programa')
# ('programa', 'lea')
# ('lea', 'reviews')
# ('reviews', 'escritas')
# ('escritas', 'personas')
# ('personas', 'entienda')
# ('entienda', 'emociones')
# ('emociones', 'procesara')
# ('procesara', 's')
# ('s', 'texto')
# ('texto', 'hara')
# ('hara', 's')
# ('s', 'programa')
# ('programa', 'entienda')
# ('entienda', 'sentimiento')
# ('sentimiento', 'miles')
# ('miles', 'humanos')
# ('humanos', 'conocera')
# ('conocera', 's')
# ('s', 'algoritmos')
# ('algoritmos', 'redes')
# ('redes', 'neuronales')
# ('neuronales', 'aprendera')
# ('aprendera', 's')
# ('s', 'usar')
# ('usar', 'tecnologi')
# ('tecnologi', 'watson')
# ('watson', 'ibm')
# ('ibm', 'img')
# ('img', 'dimensions')
# ('dimensions', 'width')
# ('width', '1000')
# ('1000', 'height')
# ('height', '500')
# ('500', 'alt')
# ('alt', 'null')
# ('null', 'copyright')
# ('copyright', 'null')
# ('null', 'url')
# ('url', 'https')
# ('https', 'images')
# ('images', 'prismic')
# ('prismic', 'io')
# ('io', 'acamica')
# ('acamica', '5ac6bd3a51b43e6fb64804d4f4ca88ddbc10f7e9_3')
# ('5ac6bd3a51b43e6fb64804d4f4ca88ddbc10f7e9_3', 'jpg')
# ('jpg', 'auto')
# ('auto', 'compress')
# ('compress', 'format')
# ('format', 'key_title')
# ('key_title', '3')
# ('3', 'title')
# ('title', 'recomendador')
# ('recomendador', 'automático')
# ('automático', 'películas')
# ('películas', 'subtitle')
# ('subtitle', 'creara')
# ('creara', 's')
# ('s', 'programa')
# ('programa', 'capaz')
# ('capaz', 'encontrar')
# ('encontrar', 'conexiones')
# ('conexiones', 'sema')
# ('sema', 'nticas')
# ('nticas', 'manera')
# ('manera', 'inteligente')
# ('inteligente', 'base')
# ('base', 'preferencias')
# ('preferencias', 'recomiende')
# ('recomiende', 'nuevas')
# ('nuevas', 'peli')
# ('peli', 'culas')
# ('culas', 'ver')
# ('ver', 'aprendera')
# ('aprendera', 's')
# ('s', 'cnicas')
# ('cnicas', 'clustering')
# ('clustering', 'svd')
# ('svd', 'computadora')
# ('computadora', 'entienda')
# ('entienda', 'humanos')
# ('humanos', 'mejor')
# ('mejor', 'mismos')
# ('mismos', 'img')
# ('img', 'dimensions')
# ('dimensions', 'width')
# ('width', '1000')
# ('1000', 'height')
# ('height', '500')
# ('500', 'alt')
# ('alt', 'null')
# ('null', 'copyright')
# ('copyright', 'null')
# ('null', 'url')
# ('url', 'https')
# ('https', 'images')
# ('images', 'prismic')
# ('prismic', 'io')
# ('io', 'acamica')
# ('acamica', '0249c890b879d86aca66c01153e114873dc6f2ff_4')
# ('0249c890b879d86aca66c01153e114873dc6f2ff_4', 'jpg')
# ('jpg', 'auto')
# ('auto', 'compress')
# ('compress', 'format')
# ('format', 'key_title')
# ('key_title', '4')
# ('4', 'title')
# ('title', 'puesta')
# ('puesta', 'producción')
# ('producción', 'subtitle')
# ('subtitle', 'pondra')
# ('pondra', 's')
# ('s', 'proyecto')
# ('proyecto', 'web')
# ('web', 'ibm')
# ('ibm', 'cloud')
# ('cloud', 'puedan')
# ('puedan', 'utilizarlo')
# ('utilizarlo', 'lográ')
# ('lográ', 'desarrollo')
# ('desarrollo', 'descubrimiento')
# ('descubrimiento', 'accesible')
# ('accesible', 'cualquiera')
# ('cualquiera', 'puedan')
# ('puedan', 'transformar')
# ('transformar', 'datos')
# ('datos', 'valor')
# ('valor', 'agregado')
# ('agregado', 'section_name_5')
# ('section_name_5', 'null')
# ('null', 'section_title_5')
# ('section_title_5', 'null')
# ('null', 'section_subtitle_5')
# ('section_subtitle_5', 'null')
# ('null', 'career_reference')
# ('career_reference', 'title')
# ('title', 'aprendizaje')
# ('aprendizaje', 'híbrido')
# ('híbrido', 'subtitle')
# ('subtitle', 'una')
# ('una', 'experiencia')
# ('experiencia', 'moderna')
# ('moderna', 'diseñada')
# ('diseñada', 'expertos')
# ('expertos', 'clases')
# ('clases', 'presenciales')
# ('presenciales', 'distancia')
# ('distancia', 'contenidos')
# ('contenidos', 'online')
# ('online', 'avances')
# ('avances', 'aprendas')
# ('aprendas', 'flexibilidad')
# ('flexibilidad', 'title')
# ('title', 'certificación')
# ('certificación', 'empresas')
# ('empresas', 'subtitle')
# ('subtitle', 'confía')
# ('confía', 'progreso')
# ('progreso', 'esfuerzo')
# ('esfuerzo', 'va')
# ('va', 'mano')
# ('mano', 'necesidades')
# ('necesidades', 'industria')
# ('industria', 'validación')
# ('validación', 'gigantes')
# ('gigantes', 'tecnológicos')
# ('tecnológicos', 'title')
# ('title', 'mentoría')
# ('mentoría', 'personalizada')
# ('personalizada', 'subtitle')
# ('subtitle', 'aprende')
# ('aprende', 'grupos')
# ('grupos', 'reducidos')
# ('reducidos', 'guía')
# ('guía', 'mentores')
# ('mentores', 'evacuar')
# ('evacuar', 'todas')
# ('todas', 'dudas')
# ('dudas', 'aprendizaje')
# ('aprendizaje', 'title')
# ('title', 'construye')
# ('construye', 'proyectos')
# ('proyectos', 'reales')
# ('reales', 'subtitle')
# ('subtitle', 'realiza')
# ('realiza', '4')
# ('4', 'proyectos')
# ('proyectos', 'robustos')
# ('robustos', 'aprende')
# ('aprende', 'haciendo')
# ('haciendo', 'devolución')
# ('devolución', 'expertos')
# ('expertos', 'industria')
# ('industria', 'código')
# ('código', 'title')
# ('title', 'habilidades')
# ('habilidades', 'humanas')
# ('humanas', 'laborales')
# ('laborales', 'subtitle')
# ('subtitle', 'entendemos')
# ('entendemos', 'importancia')
# ('importancia', 'trabajar')
# ('trabajar', 'desarrollar')
# ('desarrollar', 'habilidades')
# ('habilidades', 'complementarias')
# ('complementarias', 'destaques')
# ('destaques', 'profesional')
# ('profesional', 'cualquier')
# ('cualquier', 'ámbito')
# ('ámbito', 'section_name_6')
# ('section_name_6', 'faqs')
# ('faqs', 'section_title_6')
# ('section_title_6', 'preguntas')
# ('preguntas', 'frecuentes')
# ('frecuentes', 'section_subtitle_6')
# ('section_subtitle_6', 'null')
# ('null', 'faqs_landing')
# ('faqs_landing', 'faq_title')
# ('faq_title', 'cómo')
# ('cómo', 'puedo')
# ('puedo', 'pagar')
# ('pagar', 'inscripción')
# ('inscripción', 'y')
# ('y', 'cuotas')
# ('cuotas', 'faq_subtitle')
# ('faq_subtitle', 'según')
# ('según', 'país')
# ('país', 'residencia')
# ('residencia', 'cuentas')
# ('cuentas', 'distintas')
# ('distintas', 'opciones')
# ('opciones', 'argentina')
# ('argentina', 'tarjeta')
# ('tarjeta', 'crédito')
# ('crédito', 'débito')
# ('débito', 'débito')
# ('débito', 'automático')
# ('automático', 'cuenta')
# ('cuenta', 'bancaria')
# ('bancaria', 'cbu')
# ('cbu', 'transferencia')
# ('transferencia', 'depósito')
# ('depósito', 'cuenta')
# ('cuenta', 'efectivo')
# ('efectivo', 'red')
# ('red', 'rapipago')
# ('rapipago', 'resto')
# ('resto', 'mundo')
# ('mundo', 'tarjeta')
# ('tarjeta', 'crédito')
# ('crédito', 'faq_title')
# ('faq_title', 'ofrecen')
# ('ofrecen', 'opciones')
# ('opciones', 'financiación')
# ('financiación', 'carreras')
# ('carreras', 'faq_subtitle')
# ('faq_subtitle', 'en')
# ('en', 'acámica')
# ('acámica', 'mantenemos')
# ('mantenemos', 'compromiso')
# ('compromiso', 'todas')
# ('todas', 'personas')
# ('personas', 'interesadas')
# ('interesadas', 'puedan')
# ('puedan', 'alcanzar')
# ('alcanzar', 'objetivo')
# ('objetivo', 'formación')
# ('formación', 'por')
# ('por', 'ofrecemos')
# ('ofrecemos', 'posibilidad')
# ('posibilidad', 'pagar')
# ('pagar', 'carrera')
# ('carrera', '12')
# ('12', 'mensualidades')
# ('mensualidades', 'fijas')
# ('fijas', 'interés')
# ('interés', 'intermediarios')
# ('intermediarios', 'faq_title')
# ('faq_title', 'hay')
# ('hay', 'diferencias')
# ('diferencias', 'programas')
# ('programas', 'online')
# ('online', 'semi')
# ('semi', 'presencial')
# ('presencial', 'faq_subtitle')
# ('faq_subtitle', 'hemos')
# ('hemos', 'trabajado')
# ('trabajado', 'ambas')
# ('ambas', 'experiencias')
# ('experiencias', 'equivalentes')
# ('equivalentes', 'equipo')
# ('equipo', 'formadores')
# ('formadores', 'tamaño')
# ('tamaño', 'grupo')
# ('grupo', 'cantidad')
# ('cantidad', 'encuentros')
# ('encuentros', 'plan')
# ('plan', 'estudios')
# ('estudios', 'proyectos')
# ('proyectos', 'certificación')
# ('certificación', 'comunidad')
# ('comunidad', 'propuestas')
# ('propuestas', 'extra')
# ('extra', 'mismas')
# ('mismas', 'la')
# ('la', 'única')
# ('única', 'diferencia')
# ('diferencia', 'modalidad')
# ('modalidad', 'semi')
# ('semi', 'presencial')
# ('presencial', 'asistes')
# ('asistes', 'espacio')
# ('espacio', 'físico')
# ('físico', 'aprendizaje')
# ('aprendizaje', 'mientras')
# ('mientras', 'online')
# ('online', 'conectas')
# ('conectas', 'ya')
# ('ya', 'necesario')
# ('necesario', 'vivir')
# ('vivir', 'gran')
# ('gran', 'ciudad')
# ('ciudad', 'formarte')
# ('formarte', 'tecnología')
# ('tecnología', 'puedes')
# ('puedes', 'hacerlo')
# ('hacerlo', 'cualquier')
# ('cualquier', 'lugar')
# ('lugar', 'mundo')
# ('mundo', 'career_program')
# ('career_program', 'link_type')
# ('link_type', 'media')
# ('media', 'name')
# ('name', 'plan')
# ('plan', 'estudios_data')
# ('estudios_data', 'science_v4')
# ('science_v4', 'pdf')
# ('pdf', 'kind')
# ('kind', 'document')
# ('document', 'url')
# ('url', 'https')
# ('https', 'acamica')
# ('acamica', 'cdn')
# ('cdn', 'prismic')
# ('prismic', 'io')
# ('io', 'acamica')
# ('acamica', '17e6ed9c')
# ('17e6ed9c', '968b')
# ('968b', '4710')
# ('4710', 'b36f')
# ('b36f', 'ff5064439d9a_plan')
# ('ff5064439d9a_plan', 'estudios_data')
# ('estudios_data', 'science_v4')
# ('science_v4', 'pdf')
# ('pdf', 'size')
# ('size', '2531757')
# ('2531757', 'ordergroup')
# ('ordergroup', 'ordersection')
# ('ordersection', 'sectionname1')
# ('sectionname1', 'ocultar')
# ('ocultar', 'type')
# ('type', 'heading1')
# ('heading1', 'text')
# ('text', 'false')
# ('false', 'spans')
# ('spans', 'ordersection')
# ('ordersection', 'sectionname2')
# ('sectionname2', 'ocultar')
# ('ocultar', 'type')
# ('type', 'heading1')
# ('heading1', 'text')
# ('text', 'false')
# ('false', 'spans')
# ('spans', 'ordersection')
# ('ordersection', 'sectionname3')
# ('sectionname3', 'ocultar')
# ('ocultar', 'type')
# ('type', 'heading1')
# ('heading1', 'text')
# ('text', 'false')
# ('false', 'spans')
# ('spans', 'ordersection')
# ('ordersection', 'sectionname4')
# ('sectionname4', 'ocultar')
# ('ocultar', 'type')
# ('type', 'heading1')
# ('heading1', 'text')
# ('text', 'false')
# ('false', 'spans')
# ('spans', 'ordersection')
# ('ordersection', 'comisiones')
# ('comisiones', 'ocultar')
# ('ocultar', 'type')
# ('type', 'heading1')
# ('heading1', 'text')
# ('text', 'false')
# ('false', 'spans')
# ('spans', 'ordersection')
# ('ordersection', 'sectionname6')
# ('sectionname6', 'ocultar')
# ('ocultar', 'type')
# ('type', 'heading1')
# ('heading1', 'text')
# ('text', 'false')
# ('false', 'spans')
# ('spans', 'auth')
# ('auth', 'page')
# ('page', 'data')
# ('data', 'science')
# ('science', 'query')
# ('query', 'buildid')
# ('buildid', 'iheocvamxigwgjn_tv9et')
# ('iheocvamxigwgjn_tv9et', 'runtimeconfig')
# ('runtimeconfig', 'zendesk')
# ('zendesk', 'key')
# ('key', '104ac87e')
# ('104ac87e', 'cd4e')
# ('cd4e', '44f6')
# ('44f6', '9636')
# ('9636', 'ec8bccf6e2c9')
# ('ec8bccf6e2c9', 'enabled')
# ('enabled', 'true')
# ('true', 'dev')
# ('dev', 'false')
# ('false', 'port')
# ('port', '3000')
# ('3000', 'servername')
# ('servername', 'prod')
# ('prod', 'server')
# ('server', 'auth0_client_id')
# ('auth0_client_id', 'ul45jupc2qwpqw8b31tovtvmats8rpl5')
# ('ul45jupc2qwpqw8b31tovtvmats8rpl5', 'auth0_client_domain')
# ('auth0_client_domain', 'auth')
# ('auth', 'acamica')
# ('acamica', 'com')
# ('com', 'auth0_realm')
# ('auth0_realm', 'acamica')
# ('acamica', 'prod')
# ('prod', 'auth0_redirect_uri')
# ('auth0_redirect_uri', 'https')
# ('https', 'www')
# ('www', 'acamica')
# ('acamica', 'com')
# ('com', 'signed')
# ('signed', 'in')
# ('in', 'login_service_endpoint')
# ('login_service_endpoint', 'https')
# ('https', 'sl')
# ('sl', 'acamica')
# ('acamica', 'com')
# ('com', 'login')
# ('login', 'signed')
# ('signed', 'in')
# ('in', 'acamica_dashboard')
# ('acamica_dashboard', 'https')
# ('https', 'www')
# ('www', 'acamica')
# ('acamica', 'com')
# ('com', 'acamica_login')
# ('acamica_login', 'https')
# ('https', 'www')
# ('www', 'acamica')
# ('acamica', 'com')
# ('com', 'login')
# ('login', 'session_domain')
# ('session_domain', 'acamica')
# ('acamica', 'com')
# ('com', 'checkout_service_domain')
# ('checkout_service_domain', 'https')
# ('https', 'ms')
# ('ms', 'acamica')
# ('acamica', 'com')
# ('com', 'checkin')
# ('checkin', 'student_service_domain')
# ('student_service_domain', 'https')
# ('https', 'sl')
# ('sl', 'acamica')
# ('acamica', 'com')
# ('com', 'students')
# ('students', 'sentry_dsn')
# ('sentry_dsn', 'https')
# ('https', '872cc2f479a74d15b10b90c455d7ac20')
# ('872cc2f479a74d15b10b90c455d7ac20', 'logs')
# ('logs', 'acamica')
# ('acamica', 'net')
# ('net', '12')
# ('12', 'git_hash')
# ('git_hash', 'dev')
# ('dev', 'segment_key')
# ('segment_key', 'eg5r2nmaoprzxcmzubdalph0gtkughow')
# ('eg5r2nmaoprzxcmzubdalph0gtkughow', 'function')
# ('function', 'var')
# ('var', 'analytics')
# ('analytics', 'window')
# ('window', 'analytics')
# ('analytics', 'window')
# ('window', 'analytics')
# ('analytics', 'if')
# ('if', 'analytics')
# ('analytics', 'initialize')
# ('initialize', 'if')
# ('if', 'analytics')
# ('analytics', 'invoked')
# ('invoked', 'window')
# ('window', 'console')
# ('console', 'console')
# ('console', 'error')
# ('error', 'console')
# ('console', 'error')
# ('error', 'segment')
# ('segment', 'snippet')
# ('snippet', 'included')
# ('included', 'twice')
# ('twice', 'else')
# ('else', 'analytics')
# ('analytics', 'invoked')
# ('invoked', '0')
# ('0', 'analytics')
# ('analytics', 'methods')
# ('methods', 'tracksubmit')
# ('tracksubmit', 'trackclick')
# ('trackclick', 'tracklink')
# ('tracklink', 'trackform')
# ('trackform', 'pageview')
# ('pageview', 'identify')
# ('identify', 'reset')
# ('reset', 'group')
# ('group', 'track')
# ('track', 'ready')
# ('ready', 'alias')
# ('alias', 'debug')
# ('debug', 'page')
# ('page', 'once')
# ('once', 'off')
# ('off', 'on')
# ('on', 'analytics')
# ('analytics', 'factory')
# ('factory', 'function')
# ('function', 't')
# ('t', 'return')
# ('return', 'function')
# ('function', 'var')
# ('var', 'array')
# ('array', 'prototype')
# ('prototype', 'slice')
# ('slice', 'call')
# ('call', 'arguments')
# ('arguments', 'unshift')
# ('unshift', 't')
# ('t', 'analytics')
# ('analytics', 'push')
# ('push', 'return')
# ('return', 'analytics')
# ('analytics', 'for')
# ('for', 'var')
# ('var', 't')
# ('t', '0')
# ('0', 't')
# ('t', 'analytics')
# ('analytics', 'methods')
# ('methods', 'length')
# ('length', 't')
# ('t', 'var')
# ('var', 'analytics')
# ('analytics', 'methods')
# ('methods', 't')
# ('t', 'analytics')
# ('analytics', 'analytics')
# ('analytics', 'factory')
# ('factory', 'analytics')
# ('analytics', 'load')
# ('load', 'function')
# ('function', 't')
# ('t', 'var')
# ('var', 'n')
# ('n', 'document')
# ('document', 'createelement')
# ('createelement', 'script')
# ('script', 'n')
# ('n', 'type')
# ('type', 'text')
# ('text', 'javascript')
# ('javascript', 'n')
# ('n', 'async')
# ('async', '0')
# ('0', 'n')
# ('n', 'src')
# ('src', 'https')
# ('https', 'cdn')
# ('cdn', 'segment')
# ('segment', 'com')
# ('com', 'analytics')
# ('analytics', 'js')
# ('js', 'v1')
# ('v1', 't')
# ('t', 'analytics')
# ('analytics', 'min')
# ('min', 'js')
# ('js', 'var')
# ('var', 'document')
# ('document', 'getelementsbytagname')
# ('getelementsbytagname', 'script')
# ('script', '0')
# ('0', 'parentnode')
# ('parentnode', 'insertbefore')
# ('insertbefore', 'n')
# ('n', 'analytics')
# ('analytics', '_loadoptions')
# ('_loadoptions', 'analytics')
# ('analytics', 'snippet_version')
# ('snippet_version', '4')
# ('4', '1')
# ('1', '0')
# ('0', 'analytics')
# ('analytics', 'load')
# ('load', 'eg5r2nmaoprzxcmzubdalph0gtkughow')
# ('eg5r2nmaoprzxcmzubdalph0gtkughow', 'analytics')
# ('analytics', 'page')

# %% [markdown]
# #### Stemmer

# %%
from nltk import word_tokenize
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')

# %%
stemmer.stem('correr')
# Out:
# 'corr'

# %% [markdown]
# #### Lemmatizer

# %%
# Instalar pattern con pip install Pattern (necesita mysql como dependencia)
from pattern.es import singularize, pluralize, conjugate

print(singularize('gatos'))
print(pluralize('gato'))
print(conjugate('soy'))
# Out:
# gato
# gatos
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in _read(path, encoding, comment)
#     608             yield line
# --> 609     raise StopIteration
#     610
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-18-3f38efa46cfb> in <module>
#       4 print(singularize('gatos'))
#       5 print(pluralize('gato'))
# ----> 6 print(conjugate('soy'))
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in conjugate(self, verb, *args, **kwargs)
#    2206         i2 = self._format.get(self._default.get(id))
#    2207         i3 = self._format.get(self._default.get(self._default.get(id)))
# -> 2208         b = self.lemma(verb, parse=kwargs.get("parse", True))
#    2209         v = []
#    2210         # Get the verb lexeme and return the requested index.
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in lemma(self, verb, parse)
#    2170         """
#    2171         if dict.__len__(self) == 0:
# -> 2172             self.load()
#    2173         if verb.lower() in self._inverse:
#    2174             return self._inverse[verb.lower()]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in load(self)
#    2125         # have,,,has,,having,,,,,had,had,haven't,,,hasn't,,,,,,,hadn't,hadn't
#    2126         id = self._format[TENSES_ID[INFINITIVE]]
# -> 2127         for v in _read(self._path):
#    2128             v = v.split(",")
#    2129             dict.__setitem__(self, v[id], v)
#
# RuntimeError: generator raised StopIteration

# %%
from pattern.es import parsetree

pt = parsetree('Los perros se esconden debajo del sofá.', lemmata=True)
for sentence in pt: 
    for lemmata in sentence.lemmata: 
        print(lemmata)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in _read(path, encoding, comment)
#     608             yield line
# --> 609     raise StopIteration
#     610
#
# StopIteration:
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-651cc71f9a97> in <module>
#       1 from pattern.es import parsetree
#       2
# ----> 3 pt = parsetree('Los perros se esconden debajo del sofá.', lemmata=True)
#       4 for sentence in pt:
#       5     for lemmata in sentence.lemmata:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\es\__init__.py in parsetree(s, *args, **kwargs)
#     240     """ Returns a parsed Text from the given string.
#     241     """
# --> 242     return Text(parse(s, *args, **kwargs))
#     243
#     244
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\es\__init__.py in parse(s, *args, **kwargs)
#     234     """ Returns a tagged Unicode string.
#     235     """
# --> 236     return parser.parse(s, *args, **kwargs)
#     237
#     238
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in parse(self, s, tokenize, tags, chunks, relations, lemmata, encoding, **kwargs)
#    1170             # Tagger (required by chunker, labeler & lemmatizer).
#    1171             if tags or chunks or relations or lemmata:
# -> 1172                 s[i] = self.find_tags(s[i], **kwargs)
#    1173             else:
#    1174                 s[i] = [[w] for w in s[i]]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\es\__init__.py in find_tags(self, tokens, **kwargs)
#     207         if kwargs.get("tagset") is PAROLE:
#     208             kwargs.setdefault("map", lambda token, tag: (token, tag))
# --> 209         return _Parser.find_tags(self, tokens, **kwargs)
#     210
#     211 parser = Parser(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in find_tags(self, tokens, **kwargs)
#    1111         # ["The", "cat", "purs"] => [["The", "DT"], ["cat", "NN"], ["purs", "VB"]]
#    1112         return find_tags(tokens,
# -> 1113                     lexicon = kwargs.get("lexicon", self.lexicon or {}),
#    1114                       model = kwargs.get("model", self.model),
#    1115                  morphology = kwargs.get("morphology", self.morphology),
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in __len__(self)
#     374
#     375     def __len__(self):
# --> 376         return self._lazy("__len__")
#     377
#     378     def __iter__(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in _lazy(self, method, *args)
#     366         """
#     367         if dict.__len__(self) == 0:
# --> 368             self.load()
#     369             setattr(self, method, types.MethodType(getattr(dict, method), self))
#     370         return getattr(dict, method)(self, *args)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in load(self)
#     623     def load(self):
#     624         # Arnold NNP x
# --> 625         dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
#     626
#     627 #--- FREQUENCY -------------------------------------------------------------------------------------
#
# C:\ProgramData\Anaconda3\lib\site-packages\pattern\text\__init__.py in <genexpr>(.0)
#     623     def load(self):
#     624         # Arnold NNP x
# --> 625         dict.update(self, (x.split(" ")[:2] for x in _read(self._path) if len(x.split(" ")) > 1))
#     626
#     627 #--- FREQUENCY -------------------------------------------------------------------------------------
#
# RuntimeError: generator raised StopIteration

# %% [markdown]
# #### Bag of words

# %%
asterion_text = 'Cada nueve años entran en la casa nueve hombres \
para que yo los libere de todo mal. Oigo sus pasos o su voz en el \
fondo de las galerías de piedra y corro alegremente a buscarlos. \
La ceremonia dura pocos minutos. Uno tras otro caen sin que yo me \
ensantgriente las manos. Donde cayeron, quedan, y los cadáveres ayudan\
a distinguir una galería de las otras. Ignoro quiénes son, pero sé que \
uno de ellos profetizó, en la hora de su muerte, que alguna vez llegaría \
mi redentor, Desde entonces no me duele la soledad, porque sé que vive mi \
redeentor y al fin se levantará sobre el polvo. Si mi oído alcanzara \
los rumores del mundo, yo percibiría sus pasos. Ojalá me lleve a un \
lugar con menos galerías y menos puertas. ¿Cómo será mi redentor?, me pregunto.\
¿Será un toro o un hombre? ¿Será tal vez un toro con cara de hombre? ¿O será como yo?'

# %%
corpus = sent_tokenize(asterion_text)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer()

print(vectorizer.fit_transform(corpus).todense()[0])
print(vectorizer.vocabulary_)

# %% [markdown]
# #### Tf-idf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words=stops)
tfidf_matrix = vectorizer.fit_transform(corpus) 
print(tfidf_matrix.todense()[0])
print(vectorizer.vocabulary_)

# %% [markdown]
# #### Similitud

# %%
from sklearn.metrics.pairwise import cosine_similarity
cosine_similarity(tfidf_matrix[8], tfidf_matrix)

# %%
corpus[8]

# %%
corpus[0]
