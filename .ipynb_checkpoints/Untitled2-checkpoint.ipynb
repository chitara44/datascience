# %%
import requests
from fake_useragent import UserAgent
import pandas as pd
import bs4

# %%
products=[] #List to store name of the product
prices=[] #List to store price of the product
ratings=[] #List to store rating of the product
specifications = [] #List to store specifications of the product
df=pd.DataFrame()

# %%
user_agent = UserAgent()

# %%
product_name = input("Product Name- ")
# Out:
# Product Name-  tenis

# %%
for i in range(1,11):
    url = "https://www.linio.com.co/search?scroll=&q={0}"
    #url = "https://www.exito.com/search?_query={0}"
    url = url.format(product_name,i)
    print("url " ,url)
    ## getting the reponse from the page using get method of requests module
    page = requests.get(url, headers={"user-agent": user_agent.chrome})
    ## storing the content of the page in a variable
    html = page.content
    ## creating BeautifulSoup object
    #if (i==1):
    #    print("resultado html ", str(i), html) 
    page_soup = bs4.BeautifulSoup(html, "html.parser")
    #if (i==1):
    #    print(page_soup)
    for containers in page_soup.findAll('div',{'class':'catalogue-product row'}):
        print("container ", containers)
        name=containers.find('span', attrs={'class':'title-section'})
        print("nombre ", name)
        price=containers.find('span', attrs={'class':'original-price'})
        lowest=containers.find('span', attrs={'class':'price-main-md'})
        specification = containers.find('div', attrs={'class':'_1rcHFq'})
        products.append(name.text)
        prices.append(price.text)
        specifications.append(specification.text) if type(specification) == bs4.element.Tag  else specifications.append('NaN')
        ratings.append(lowest.text) if type(lowest) == bs4.element.Tag  else lowest.append('NaN')
    df = pd.DataFrame({'Product Name':products,'Price':prices, 'specification':specifications, 'Rating':ratings})
# Out:
# url  https://www.linio.com.co/search?scroll=&q=tenis
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-adidas-hombre-moda-supercourt-s1n7ux?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=AD274FA0QP96FLCO&amp;position=1&amp;sku=AD274FA0QP96FLCO" title="Tenis Adidas Hombre Moda Supercourt">
# <meta content="Tenis Adidas Hombre Moda Supercourt" itemprop="name"/>
# <meta content="AD274FA0QP96FLCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/509bfaeefc8061a76fac927e320051d1-product.jpg" itemprop="image"/>
# <meta content="Adidas" itemprop="brand"/>
# <meta content="Marca=AdidasModelo=SupercourtTipo=Tenis modaGénero=HombreHorma=NormalMaterial=CueroMaterial del interior=Sintético" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/509bfaeefc8061a76fac927e320051d1-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/509bfaeefc8061a76fac927e320051d1-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis Adidas Hombre Moda Supercourt" class="image" data-lazy="//i.linio.com/p/509bfaeefc8061a76fac927e320051d1-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis Adidas Hombre Moda Supercourt...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="191990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-adidas-hombre-moda-supercourt-s1n7ux" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$319.990</span>
# <span class="discount">- 40%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $191.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-adidas-hombre-moda-supercourt-s1n7ux" title="Tenis Adidas Hombre Moda Supercourt">Ver producto</a>
# <ul><li>Marca=Adidas</li><li>Modelo=Supercourt</li><li>Tipo=Tenis moda</li><li>Género=Hombre</li><li>Horma=Normal</li><li>Material=Cuero</li><li>Material del interior=Sintético</li></ul>
# </div>
# <a href="/p/tenis-adidas-hombre-moda-supercourt-s1n7ux" title="Tenis Adidas Hombre Moda Supercourt">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis Adidas Hombre Moda Supercourt...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-nike-hombre-running-todos-bq3198-002-negro-n44g0i?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=NI235FA16XW13LCO&amp;position=2&amp;sku=NI235FA16XW13LCO" title="Tenis Nike Hombre Running Todos  Bq3198-002 -Negro">
# <meta content="Tenis Nike Hombre Running Todos  Bq3198-002 -Negro" itemprop="name"/>
# <meta content="NI235FA16XW13LCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/1dafc47934609b0eb1d036a295a83555-product.jpg" itemprop="image"/>
# <meta content="Nike" itemprop="brand"/>
# <meta content="Marca=NikeDisciplina=RunningMaterial de la suela=GomaTipo=Tenis deportivosHecho en=VietnamGénero=HombreMaterial del interior=SintéticoNombre del fabricante o importador=Northbay International INC.Horma=NormalMaterial=SintéticoTipo de caña=No aplicaTranspirabilidad de la tela=NoTemporada=Toda temporadaModelo=BQ3198002NIT=409352Registro SIC=409352" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/1dafc47934609b0eb1d036a295a83555-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/1dafc47934609b0eb1d036a295a83555-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis Nike Hombre Running Todos  Bq3198-002 -Negro" class="image" data-lazy="//i.linio.com/p/1dafc47934609b0eb1d036a295a83555-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis Nike Hombre Running Todos  Bq3198-...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="159990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-nike-hombre-running-todos-bq3198-002-negro-n44g0i" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$249.990</span>
# <span class="discount">- 36%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $159.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-nike-hombre-running-todos-bq3198-002-negro-n44g0i" title="Tenis Nike Hombre Running Todos  Bq3198-002 -Negro">Ver producto</a>
# <ul><li>Marca=Nike</li><li>Disciplina=Running</li><li>Material de la suela=Goma</li><li>Tipo=Tenis deportivos</li><li>Hecho en=Vietnam</li><li>Género=Hombre</li><li>Material del interior=Sintético</li><li>Nombre del fabricante o importador=Northbay International INC.</li><li>Horma=Normal</li><li>Material=Sintético</li><li>Tipo de caña=No aplica</li><li>Transpirabilidad de la tela=No</li><li>Temporada=Toda temporada</li><li>Modelo=BQ3198</li><li>002</li><li>NIT=40935</li><li>2</li><li>Registro SIC=40935</li><li>2</li></ul>
# </div>
# <a href="/p/tenis-nike-hombre-running-todos-bq3198-002-negro-n44g0i" title="Tenis Nike Hombre Running Todos  Bq3198-002 -Negro">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis Nike Hombre Running Todos  Bq3198-...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-asics-hombre-running-gel-contend-6-ymloc9?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=AS187FA03UUP3LCO&amp;position=3&amp;sku=AS187FA03UUP3LCO" title="Tenis Asics Hombre Running Gel-Contend 6">
# <meta content="Tenis Asics Hombre Running Gel-Contend 6" itemprop="name"/>
# <meta content="AS187FA03UUP3LCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/6d819ee70125b38bb469f29d9fe66ddc-product.jpg" itemprop="image"/>
# <meta content="Asics" itemprop="brand"/>
# <meta content="Marca=AsicsModelo=1011A667.021Género=HombreTipo=Tenis de runningHorma=NormalMaterial=SintéticoMaterial de la suela=Goma" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/6d819ee70125b38bb469f29d9fe66ddc-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/6d819ee70125b38bb469f29d9fe66ddc-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis Asics Hombre Running Gel-Contend 6" class="image" data-lazy="//i.linio.com/p/6d819ee70125b38bb469f29d9fe66ddc-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis Asics Hombre Running Gel-Contend 6...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="129990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-asics-hombre-running-gel-contend-6-ymloc9" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$199.990</span>
# <span class="discount">- 35%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $129.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-asics-hombre-running-gel-contend-6-ymloc9" title="Tenis Asics Hombre Running Gel-Contend 6">Ver producto</a>
# <ul><li>Marca=Asics</li><li>Modelo=1011A667.021</li><li>Género=Hombre</li><li>Tipo=Tenis de running</li><li>Horma=Normal</li><li>Material=Sintético</li><li>Material de la suela=Goma</li></ul>
# </div>
# <a href="/p/tenis-asics-hombre-running-gel-contend-6-ymloc9" title="Tenis Asics Hombre Running Gel-Contend 6">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis Asics Hombre Running Gel-Contend 6...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-hombre-moda-shuffle-puma-309668-03-vdsfh1?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=PU204FA0D7D2BLCO&amp;position=4&amp;sku=PU204FA0D7D2BLCO" title="Tenis  Hombre Moda Shuffle Puma 309668 03">
# <meta content="Tenis  Hombre Moda Shuffle Puma 309668 03" itemprop="name"/>
# <meta content="PU204FA0D7D2BLCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/13425238d5dbcdc6b4c079500d0127f3-product.jpg" itemprop="image"/>
# <meta content="Puma" itemprop="brand"/>
# <meta content="Marca=PumaModelo=309668 03Tipo=Tenis modaGénero=HombreHorma=NormalMaterial=SintéticoMaterial del interior=Sintético" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/13425238d5dbcdc6b4c079500d0127f3-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/13425238d5dbcdc6b4c079500d0127f3-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis  Hombre Moda Shuffle Puma 309668 03" class="image" data-lazy="//i.linio.com/p/13425238d5dbcdc6b4c079500d0127f3-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis  Hombre Moda Shuffle Puma 309668 0...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="159990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-hombre-moda-shuffle-puma-309668-03-vdsfh1" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$229.990</span>
# <span class="discount">- 30%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $159.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-hombre-moda-shuffle-puma-309668-03-vdsfh1" title="Tenis  Hombre Moda Shuffle Puma 309668 03">Ver producto</a>
# <ul><li>Marca=Puma</li><li>Modelo=309668 03</li><li>Tipo=Tenis moda</li><li>Género=Hombre</li><li>Horma=Normal</li><li>Material=Sintético</li><li>Material del interior=Sintético</li></ul>
# </div>
# <a href="/p/tenis-hombre-moda-shuffle-puma-309668-03-vdsfh1" title="Tenis  Hombre Moda Shuffle Puma 309668 03">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis  Hombre Moda Shuffle Puma 309668 0...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-de-running-adidas-mujer-sooraj-tptaa1?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=AD274FA0JYX9BLCO&amp;position=5&amp;sku=AD274FA0JYX9BLCO" title="Tenis de Running Adidas Mujer Sooraj">
# <meta content="Tenis de Running Adidas Mujer Sooraj" itemprop="name"/>
# <meta content="AD274FA0JYX9BLCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/54b87b04a5f684b79be0c15348fd0024-product.jpg" itemprop="image"/>
# <meta content="Adidas" itemprop="brand"/>
# <meta content="Marca=AdidasModelo=SOORAJGénero=MujerTipo=Tenis de runningHorma=NormalMaterial=SintéticoMaterial de la suela=Goma" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/54b87b04a5f684b79be0c15348fd0024-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/54b87b04a5f684b79be0c15348fd0024-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis de Running Adidas Mujer Sooraj" class="image" data-lazy="//i.linio.com/p/54b87b04a5f684b79be0c15348fd0024-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis de Running Adidas Mujer Sooraj...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="139990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-de-running-adidas-mujer-sooraj-tptaa1" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$199.990</span>
# <span class="discount">- 30%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $139.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-de-running-adidas-mujer-sooraj-tptaa1" title="Tenis de Running Adidas Mujer Sooraj">Ver producto</a>
# <ul><li>Marca=Adidas</li><li>Modelo=SOORAJ</li><li>Género=Mujer</li><li>Tipo=Tenis de running</li><li>Horma=Normal</li><li>Material=Sintético</li><li>Material de la suela=Goma</li></ul>
# </div>
# <a href="/p/tenis-de-running-adidas-mujer-sooraj-tptaa1" title="Tenis de Running Adidas Mujer Sooraj">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis de Running Adidas Mujer Sooraj...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-new-balance-mujer-moda-45x-new-balance-ws45xra1-negro-n4pvkw?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=NE770FA16N687LCO&amp;position=6&amp;sku=NE770FA16N687LCO" title="Tenis New Balance Mujer Moda 45X NEW BALANCE WS45XRA1-Negro">
# <meta content="Tenis New Balance Mujer Moda 45X NEW BALANCE WS45XRA1-Negro" itemprop="name"/>
# <meta content="NE770FA16N687LCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/c56dea60e76d33ca5b02039bb11d3ae6-product.jpg" itemprop="image"/>
# <meta content="New Balance" itemprop="brand"/>
# <meta content="Tipo=Tenis modaRegistro SIC=444441140Marca=New BalanceAltura de la plataforma=Sin plataformaNIT=444441140Género=MujerMaterial del interior=SintéticoMaterial=SintéticoHorma=NormalTipo de caña=No aplicaMaterial de la suela=GomaTemporada=Toda temporadaNombre del fabricante o importador=Balance Management CORPHecho en=IndonesiaModelo=WS45XRA1" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/c56dea60e76d33ca5b02039bb11d3ae6-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/c56dea60e76d33ca5b02039bb11d3ae6-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis New Balance Mujer Moda 45X NEW BALANCE WS45XRA1-Negro" class="image" data-lazy="//i.linio.com/p/c56dea60e76d33ca5b02039bb11d3ae6-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis New Balance Mujer Moda 45X NEW BAL...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="189990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-new-balance-mujer-moda-45x-new-balance-ws45xra1-negro-n4pvkw" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$339.990</span>
# <span class="discount">- 44%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $189.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-new-balance-mujer-moda-45x-new-balance-ws45xra1-negro-n4pvkw" title="Tenis New Balance Mujer Moda 45X NEW BALANCE WS45XRA1-Negro">Ver producto</a>
# <ul><li>Tipo=Tenis moda</li><li>Registro SIC=444441140</li><li>Marca=New Balance</li><li>Altura de la plataforma=Sin plataforma</li><li>NIT=444441140</li><li>Género=Mujer</li><li>Material del interior=Sintético</li><li>Material=Sintético</li><li>Horma=Normal</li><li>Tipo de caña=No aplica</li><li>Material de la suela=Goma</li><li>Temporada=Toda temporada</li><li>Nombre del fabricante o importador=Balance Management CORP</li><li>Hecho en=Indonesia</li><li>Modelo=WS45XRA1</li></ul>
# </div>
# <a href="/p/tenis-new-balance-mujer-moda-45x-new-balance-ws45xra1-negro-n4pvkw" title="Tenis New Balance Mujer Moda 45X NEW BALANCE WS45XRA1-Negro">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis New Balance Mujer Moda 45X NEW BAL...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-moda-adidas-mujer-crazychaos-toq5ey?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=AD274FA0KFALELCO&amp;position=7&amp;sku=AD274FA0KFALELCO" title="Tenis Moda Adidas Mujer Crazychaos">
# <meta content="Tenis Moda Adidas Mujer Crazychaos" itemprop="name"/>
# <meta content="AD274FA0KFALELCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/4d861d13d0fdb8010d73219b560f9943-product.jpg" itemprop="image"/>
# <meta content="Adidas" itemprop="brand"/>
# <meta content="Marca=AdidasModelo=CRAZYCHAOSTipo=Tenis modaGénero=MujerHorma=NormalMaterial=CueroMaterial del interior=Sintético" itemprop="description"/>
# <div class="image-container">
# <figure>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/4d861d13d0fdb8010d73219b560f9943-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/4d861d13d0fdb8010d73219b560f9943-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis Moda Adidas Mujer Crazychaos" class="image" data-lazy="//i.linio.com/p/4d861d13d0fdb8010d73219b560f9943-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis Moda Adidas Mujer Crazychaos...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="179990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-moda-adidas-mujer-crazychaos-toq5ey" itemprop="url">
# <link href="http://schema.org/InStock" itemprop="availability"/>
# <div class="discount-container">
# <span class="original-price">$259.990</span>
# <span class="discount">- 30%</span>
# </div>
# <div class="">
# <div class="lowest-price">
# <span class="price-main-md">
#       $179.990
#     </span>
# </div>
# </div>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# <img alt="Black Week" class="lighthouse" src="https://s3.amazonaws.com/fms-live/085c4ba6-2c72-11eb-bb92-6e42975fe331.png" title="Black Week"/>
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-moda-adidas-mujer-crazychaos-toq5ey" title="Tenis Moda Adidas Mujer Crazychaos">Ver producto</a>
# <ul><li>Marca=Adidas</li><li>Modelo=CRAZYCHAOS</li><li>Tipo=Tenis moda</li><li>Género=Mujer</li><li>Horma=Normal</li><li>Material=Cuero</li><li>Material del interior=Sintético</li></ul>
# </div>
# <a href="/p/tenis-moda-adidas-mujer-crazychaos-toq5ey" title="Tenis Moda Adidas Mujer Crazychaos">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis Moda Adidas Mujer Crazychaos...</span>
# container  <div class="catalogue-product row" data-ad-id="" itemscope="" itemtype="http://schema.org/Product">
# <a href="/p/tenis-mujer-running-patriot-12-asics-1012a705400-azul-va8cda?qid=21cf08da3da89d8df253bf99cb91cdf2&amp;oid=AS187FA0GOX7BLCO&amp;position=8&amp;sku=AS187FA0GOX7BLCO" title="Tenis  Mujer Running Patriot 12 Asics 1012A705.400-Azul">
# <meta content="Tenis  Mujer Running Patriot 12 Asics 1012A705.400-Azul" itemprop="name"/>
# <meta content="AS187FA0GOX7BLCO" itemprop="sku"/>
# <meta content="" itemprop="model"/>
# <meta content="//i.linio.com/p/54db53e5dda7c2474db26519236791af-product.jpg" itemprop="image"/>
# <meta content="Asics" itemprop="brand"/>
# <meta content="Marca: AsicsModelo: 1012A705.400Género: MujerTipo: Tenis deportivosHorma: NormalMaterial: SintéticoMaterial de la suela: Goma" itemprop="description"/>
# <div class="image-container">
# <figure class="product-unavailable">
# <span class="warning-label">Agotado</span>
# <picture class="image-wrapper">
# <source data-lazy="//i.linio.com/p/54db53e5dda7c2474db26519236791af-catalog.webp" type="image/webp"/>
# <source data-lazy="//i.linio.com/p/54db53e5dda7c2474db26519236791af-catalog.jpg" type="image/jpeg"/>
# <img alt="Tenis  Mujer Running Patriot 12 Asics 1012A705.400-Azul" class="image" data-lazy="//i.linio.com/p/54db53e5dda7c2474db26519236791af-catalog.jpg" loading="lazy" src="..."/>
# </picture>
# </figure>
# </div>
# <div class="detail-container">
# <p>
# <span class="title-section">Tenis  Mujer Running Patriot 12 Asics 10...</span>
# </p>
# <div class="price-section" itemprop="offers" itemscope="" itemtype="http://schema.org/Offer">
# <meta content="129990.00" itemprop="price">
# <meta content="COP" itemprop="priceCurrency">
# <meta content="/p/tenis-mujer-running-patriot-12-asics-1012a705400-azul-va8cda" itemprop="url">
# <link href="http://schema.org/OutOfStock" itemprop="availability"/>
# </meta></meta></meta></div>
# </div>
# </a>
# <div class="badge-container hidden-md-up">
# <div class="badge-pill-refactor">
# <div class="badge-pill-free-shipping badge-text-refactor">Envío gratis</div>
# </div>
# </div>
# <div class="detail-container">
# <div class="top-pills">
# </div>
# <div class="specs-section">
# <a class="btn btn-primary" href="/p/tenis-mujer-running-patriot-12-asics-1012a705400-azul-va8cda" title="Tenis  Mujer Running Patriot 12 Asics 1012A705.400-Azul">Ver producto</a>
# <ul><li>Marca: Asics</li><li>Modelo: 1012A705.400</li><li>Género: Mujer</li><li>Tipo: Tenis deportivos</li><li>Horma: Normal</li><li>Material: Sintético</li><li>Material de la suela: Goma</li></ul>
# </div>
# <a href="/p/tenis-mujer-running-patriot-12-asics-1012a705400-azul-va8cda" title="Tenis  Mujer Running Patriot 12 Asics 1012A705.400-Azul">
# <div class="delivery-section">
# <div class="free-container">
# <span class="hidden-section free-text badge-text">Envío gratis</span>
# </div>
# <div class="rating-content">
# </div>
# </div>
# </a>
# </div>
# </div>
# nombre  <span class="title-section">Tenis  Mujer Running Patriot 12 Asics 10...</span>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ac30ecbba1af> in <module>
#      22         specification = containers.find('div', attrs={'class':'_1rcHFq'})
#      23         products.append(name.text)
# ---> 24         prices.append(price.text)
#      25         specifications.append(specification.text) if type(specification) == bs4.element.Tag  else specifications.append('NaN')
#      26         ratings.append(lowest.text) if type(lowest) == bs4.element.Tag  else lowest.append('NaN')
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
df.head()

# %%
df['Product Name'] = 'bottle'
df.head()

# %%
df['Price'] = df['Price'].str.lstrip('₹')
df['Price'] = df['Price'].replace({',':''}, regex=True)
df.head()

# %%
df['Pack'], df['color'] = df['specification'].str.split(',', 1).str
del df['specification']
df.head()

# %%
import numpy as np
import seaborn as sns
df['Price'] = df['Price'].astype(np.float)
sns.boxplot(x=df['Price'])

# %%
sns.barplot(x=df['Price'], y=df['color'])

# %%
df['Rating'] = df['Rating'].astype(np.float)
sns.barplot(x=df['Rating'], y=df['color'])

# %%
sns.barplot(x=df['Rating'], y=df['Price'])

# %%
sns.lineplot(x=df['Rating'], y=df['Price'])
