# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %% [markdown]
# cargamos el dataset

# %%
path_dataset = 'expdata2.csv'
df = pd.read_csv(path_dataset, parse_dates=['fecha'])
#df = df[df.sb  int('16'), inplace = True]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 11 columns):
# idSorteo    512 non-null int64
# fecha       512 non-null datetime64[ns]
# tipo        512 non-null object
# ganador     512 non-null object
# nuevo       512 non-null object
# n1          512 non-null int64
# n2          512 non-null int64
# n3          512 non-null int64
# n4          512 non-null int64
# n5          512 non-null int64
# sb          512 non-null int64
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 44.1+ KB

# %%
df.describe()
# Out:
#           idSorteo         n1          n2          n3          n4          n5  \
# count   512.000000  512.00000  512.000000  512.000000  512.000000  512.000000
# mean   1797.394531    7.34375   15.066406   22.078125   29.230469   36.910156
# std      73.809432    5.72759    7.602881    7.864667    7.498311    5.682029
# min    1670.000000    1.00000    2.000000    3.000000    5.000000   13.000000
# 25%    1733.750000    3.00000    9.000000   16.000000   24.000000   34.000000
# 50%    1797.500000    6.00000   14.000000   22.500000   30.500000   39.000000
# 75%    1861.250000   10.00000   20.000000   28.000000   35.000000   41.000000
# max    1924.000000   27.00000   40.000000   41.000000   42.000000   43.000000
#
#                sb
# count  512.000000
# mean     8.429688
# std      5.071595
# min      1.000000
# 25%      4.000000
# 50%      8.000000
# 75%     12.000000
# max     45.000000

# %%
df.head(20)
# Out:
#     idSorteo      fecha tipo ganador nuevo  n1  n2  n3  n4  n5  sb
# 0       1924 2019-09-25   Tr      NO    SI   4  11  14  16  36  15
# 1       1924 2019-09-25   Re      NO    SI   9  10  14  41  42  11
# 2       1923 2019-09-21   Tr      NO    SI  21  23  26  37  43  11
# 3       1923 2019-09-21   Re      NO    SI   2  25  26  28  35   1
# 4       1922 2019-09-18   Tr      NO    SI  18  23  28  33  35  12
# 5       1922 2019-09-18   Re      NO    SI  14  20  23  33  38  10
# 6       1921 2019-09-14   Tr      NO    SI   1  19  31  37  39  11
# 7       1921 2019-09-14   Re      NO    SI   1   2   5  21  35  12
# 8       1920 2019-11-09   Tr      NO    SI   6  19  23  25  41   7
# 9       1920 2019-11-09   Re      NO    SI  10  18  23  29  41   7
# 10      1919 2019-07-09   Tr      NO    SI  11  14  20  30  34   7
# 11      1919 2019-07-09   Re      NO    SI   4   7  11  39  43   6
# 12      1918 2019-04-09   Tr      NO    SI  20  11  18  23  43  14
# 13      1918 2019-04-09   Re      NO    SI   2   7  16  26  41   2
# 14      1917 2019-08-31   Tr      NO    SI  17  18  33  41  42   8
# 15      1917 2019-08-31   Re      NO    SI   8  15  21  27  32   3
# 16      1916 2019-08-28   Tr      NO    SI  11  18  29  35  37   6
# 17      1916 2019-08-28   Re      NO    SI   3  15  26  31  34   3
# 18      1915 2019-08-24   Tr      NO    SI   4   8  12  17  35  12
# 19      1915 2019-08-24   Re      NO    SI  17  24  25  40  42   4

# %%
propiedades = ["Tr"]
df_tr = df[df.tipo.isin(propiedades)]
print(df_tr)
# Out:
#      idSorteo      fecha tipo ganador nuevo  n1  n2  n3  n4  n5  sb
# 47       1901 2019-06-07   Re      NO    SI  15  20  25  35  43   9
# 49       1900 2019-03-07   Re      NO    SI   3   4  22  38  43  12
# 51       1899 2019-06-29   Re      NO    SI   8  26  31  38  39  11
# 53       1898 2019-06-26   Re      NO    SI  18  31  33  34  42   8
# 55       1898 2019-06-26   Re      NO    SI  18  31  33  34  42   8
# 57       1897 2019-06-22   Re      NO    SI   2   5  12  38  40   7
# 59       1896 2019-06-19   Re      NO    SI   9  10  26  30  36  10
# ..        ...        ...  ...     ...   ...  ..  ..  ..  ..  ..  ..
# 453      1699 2017-07-29   Re      NO    SI  11  14  23  30  35  12
# 455      1698 2017-07-26   Re      NO    SI  17  18  31  34  39  14
# 457      1697 2017-07-22   Re      NO    SI   4  29  30  31  42  16
# 459      1696 2017-07-19   Re      NO    SI   9  10  27  35  42  12
# 461      1695 2017-07-15   Re      NO    SI  26  29  30  35  36   6
# 463      1694 2017-12-07   Re      NO    SI   1  11  19  20  37   5
# 465      1693 2017-08-07   Re      NO    SI  13  15  16  31  37  14
# 467      1692 2017-05-07   Re      NO    SI  16  25  31  32  34   5
# 469      1691 2017-01-07   Re      NO    SI   4  17  21  35  40   1
# 471      1690 2017-06-28   Re      NO    SI   4   7   8  24  41  13
# 473      1689 2017-06-24   Re      NO    SI   1   3   7  16  32   4
# 475      1688 2017-06-21   Re      NO    SI  12  21  25  27  34  10
# 477      1687 2017-06-17   Re      NO    SI  10  19  32  38  40  14
# 479      1686 2017-06-14   Re      NO    SI   5  13  17  22  40  13
# 481      1685 2017-10-06   Re      NO    SI  22  25  26  40  43  14
# 483      1684 2017-07-06   Re      NO    SI   3  13  16  20  26   1
# 485      1683 2017-03-06   Re      NO    SI   8  10  19  22  30   3
# 487      1682 2017-05-31   Re      NO    SI   5  20  21  25  26   3
# 489      1681 2017-05-27   Re      NO    SI  17  28  29  37  40  14
# 491      1680 2017-05-24   Re      NO    SI  11  28  31  33  41   7
# 493      1679 2017-05-20   Re      NO    SI   4  13  20  31  33   8
# 495      1678 2017-05-17   Re      NO    SI   1  20  25  27  34   3
# 497      1677 2017-05-13   Re      NO    SI  14  22  24  25  32   7
# 499      1676 2017-10-05   Re      NO    SI   3   4  29  40  43   4
# 501      1675 2017-06-05   Re      NO    SI   3   5   8  20  24  14
# 503      1674 2017-03-05   Re      NO    SI   5  12  15  20  42  14
# 505      1673 2017-04-29   Re      NO    SI   8  21  22  37  38   4
# 507      1672 2017-04-26   Re      NO    SI   9  12  16  28  38   1
# 509      1671 2017-04-22   Re      NO    SI   3   9  10  21  40  10
# 511      1670 2017-04-19   Re      NO    SI   2   4  14  34  31  40
#
# [255 rows x 11 columns]

# %%
sbs = ["01", "02", "03", "04", "05", "06","07", "08", "09", "10", "11", "12","13", "14", "15", "16"]
df_sb_tr = df_tr[df_tr.sb.isin(sbs)]
df_sb_re = df_re[df_re.sb.isin(sbs)]

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="sb", data=df_sb_tr)

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="sb", data=df_sb_re)

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="sb", data=df)

# %%
sns.set(style="darkgrid")
x= df.sb
ax = sns.distplot(x, bins=16)

# %%
df.head()
# Out:
#    idSorteo      fecha tipo ganador nuevo  n1  n2  n3  n4  n5  sb
# 0      1924 2019-09-25   Tr      NO    SI   4  11  14  16  36  15
# 1      1924 2019-09-25   Re      NO    SI   9  10  14  41  42  11
# 2      1923 2019-09-21   Tr      NO    SI  21  23  26  37  43  11
# 3      1923 2019-09-21   Re      NO    SI   2  25  26  28  35   1
# 4      1922 2019-09-18   Tr      NO    SI  18  23  28  33  35  12

# %%
df_tr_fusion = []
df_re_fusion = []
unuseful_columns = ['fecha','tipo','ganador', 'nuevo', 'sb']
df_tr_fusion = df_tr.drop(unuseful_columns, axis=1)
df_re_fusion = df_re.drop(unuseful_columns, axis=1)
filas = int(df_sb_tr.shape[0])
df_tr_fusion.info()
print(filas)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 510
# Data columns (total 6 columns):
# idSorteo    257 non-null int64
# n1          257 non-null int64
# n2          257 non-null int64
# n3          257 non-null int64
# n4          257 non-null int64
# n5          257 non-null int64
# dtypes: int64(6)
# memory usage: 14.1 KB
# 256

# %% [markdown]
# los numeros de las columnas n1-n5 seran fusionadas, seran transformados a una sola dimension, para poder determinar la frecuencia con la que acontecen, en primera instancia seran separados por tipo de sorteo, y en el nuevo dataset tendremos el numero del sorteo y el numero

# %%
print(df_tr_fusion)
# Out:
#      idSorteo  n1  n2  n3  n4  n5
# 0        1924   4  11  14  16  36
# 2        1923  21  23  26  37  43
# 4        1922  18  23  28  33  35
# 6        1921   1  19  31  37  39
# 8        1920   6  19  23  25  41
# 10       1919  11  14  20  30  34
# 12       1918  20  11  18  23  43
# 14       1917  17  18  33  41  42
# 16       1916  11  18  29  35  37
# 18       1915   4   8  12  17  35
# 20       1914   6   8  13  28  29
# 22       1913  10  12  25  27  41
# 24       1912   7  22  25  36  37
# 26       1911   6  29  34  41  42
# 28       1910   6  27  32  40  42
# 30       1909   2  11  33  36  38
# 32       1908  10  20  25  28  30
# 34       1907   9  13  18  19  33
# 36       1906   3  12  24  25  26
# 38       1905  10  11  15  31  38
# 40       1904   6  12  14  15  38
# 42       1903   2  18  29  37  39
# 44       1902   9  12  31  33  43
# 46       1901   1   8  21  34  35
# 48       1900   1   2   3  10  31
# 50       1899   2  12  16  26  30
# 52       1898   6  12  15  26  35
# 54       1898   6  12  15  26  35
# 56       1897  15  16  24  26  32
# 58       1896   4  10  20  32  33
# ..        ...  ..  ..  ..  ..  ..
# 452      1699   3  13  14  17  23
# 454      1698   1  27  31  34  36
# 456      1697   6   9  15  37  42
# 458      1696  14  15  20  25  40
# 460      1695   7  23  24  34  39
# 462      1694   7  23  30  33  36
# 464      1693   1   7  12  19  21
# 466      1692  20  22  25  37  43
# 468      1691  10  16  18  35  40
# 470      1690  18  22  32  37  39
# 472      1689   3   4   9  20  32
# 474      1688   4   6  14  17  29
# 476      1687   9  20  24  31  33
# 478      1686   2   9  12  34  40
# 480      1685  13  20  26  29  40
# 482      1684   3  20  33  34  40
# 484      1683   3  26  33  34  38
# 486      1682  12  13  25  31  42
# 488      1681   8  12  20  36  40
# 490      1680   7  22  29  32  41
# 492      1679   1  11  28  31  41
# 494      1678  15  21  26  28  36
# 496      1677  11  19  27  28  37
# 498      1676  12  19  22  35  38
# 500      1675   1  20  36  39  43
# 502      1674   5   6   7  12  37
# 504      1673   6  19  25  28  36
# 506      1672   1   2  25  31  33
# 508      1671  15  28  36  37  41
# 510      1670  11  17  18  34  43
#
# [257 rows x 6 columns]

# %%
main_columns = ['n1','n2','n3', 'n4', 'n5']

df_1d_fusion = df_tr_fusion.iloc[1:filas:1,0:2:1]
df_1d_fusion = df_1d_fusion.rename(columns = {'n1':'num'})


df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:3:2]
df_temp_fusion = df_temp_fusion.rename(columns = {'n2':'num'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)

df_1d_fusion = df_final

df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:4:3]
df_temp_fusion = df_temp_fusion.rename(columns = {'n3':'num'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)

df_1d_fusion = df_final

df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:5:4]
df_temp_fusion = df_temp_fusion.rename(columns = {'n4':'num'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)

df_1d_fusion = df_final

df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:6:5]
df_temp_fusion = df_temp_fusion.rename(columns = {'n5':'num'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)
df_final
#df_final.info()
# Out:
#       idSorteo  num
# 0         1923   21
# 1         1922   18
# 2         1921    1
# 3         1920    6
# 4         1919   11
# 5         1918   20
# 6         1917   17
# 7         1916   11
# 8         1915    4
# 9         1914    6
# 10        1913   10
# 11        1912    7
# 12        1911    6
# 13        1910    6
# 14        1909    2
# 15        1908   10
# 16        1907    9
# 17        1906    3
# 18        1905   10
# 19        1904    6
# 20        1903    2
# 21        1902    9
# 22        1901    1
# 23        1900    1
# 24        1899    2
# 25        1898    6
# 26        1898    6
# 27        1897   15
# 28        1896    4
# 29        1895   10
# ...        ...  ...
# 1249      1700   37
# 1250      1699   23
# 1251      1698   36
# 1252      1697   42
# 1253      1696   40
# 1254      1695   39
# 1255      1694   36
# 1256      1693   21
# 1257      1692   43
# 1258      1691   40
# 1259      1690   39
# 1260      1689   32
# 1261      1688   29
# 1262      1687   33
# 1263      1686   40
# 1264      1685   40
# 1265      1684   40
# 1266      1683   38
# 1267      1682   42
# 1268      1681   40
# 1269      1680   41
# 1270      1679   41
# 1271      1678   36
# 1272      1677   37
# 1273      1676   38
# 1274      1675   43
# 1275      1674   37
# 1276      1673   36
# 1277      1672   33
# 1278      1671   41
#
# [1279 rows x 2 columns]

# %%
main_columns = ['n1','n2','n3', 'n4', 'n5']

df_1d_fusion = df_tr_fusion.iloc[1:filas:1,0:3:1]
df_1d_fusion = df_1d_fusion.rename(columns = {'n1':'num1', 'n2': 'num2'})

df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:4:2]
df_temp_fusion = df_temp_fusion.rename(columns = {'n2':'num1', 'n3': 'num2'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)

df_1d_fusion = df_final

df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:5:3]
df_temp_fusion = df_temp_fusion.rename(columns = {'n3':'num1', 'n4': 'num2'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)
df_final.info()
df_1d_fusion = df_final

df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:5:4]
df_temp_fusion = df_temp_fusion.rename(columns = {'n4':'num', 'n5': 'num2'})
df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)

df_1d_fusion = df_final
df_final

#df_temp_fusion = df_tr_fusion.iloc[0:filas:1,0:6:5]
#df_temp_fusion = df_temp_fusion.rename(columns = {'n5':'num'})
#df_final = pd.concat([df_1d_fusion, df_temp_fusion], ignore_index=True)

#df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 3 columns):
# idSorteo    767 non-null int64
# num1        767 non-null int64
# num2        255 non-null float64
# dtypes: float64(1), int64(2)
# memory usage: 18.1 KB
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
df_final.describe()
# Out:
#           idSorteo        num1        num2
# count  1023.000000  767.000000  511.000000
# mean   1797.986315   14.844850   21.990215
# std      73.351070    9.254632   10.355348
# min    1671.000000    1.000000    2.000000
# 25%    1734.500000    7.000000   14.000000
# 50%    1798.000000   14.000000   22.000000
# 75%    1861.000000   22.000000   31.000000
# max    1924.000000   39.000000   42.000000

# %%
sns.set(style="darkgrid")
ax = sns.countplot(x="num", data=df_final)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-523c011b1e59> in <module>
#       1 sns.set(style="darkgrid")
# ----> 2 ax = sns.countplot(x="num", data=df_final)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'num'

# %%
sns.set(style="darkgrid")
x= df_final.num
ax = sns.distplot(x, bins=43)

# %%
g = sns.jointplot("num", "idSorteo",  data=df_final, kind="reg", xlim=(1, 43), ylim=(1650, 1940), color="m", height=15)

# %%
sns.pairplot(df_final, hue="num")

# %%
grid = sns.FacetGrid(df_final, col="num", hue="num", palette="tab20c", col_wrap=4, height=4)
grid.map(plt.axhline, y=0, ls=":", c=".5")
grid.map(plt.plot, "num", "idSorteo", marker="o")
grid.set(xticks=np.arange(5), yticks=[-3, 3], xlim=(-.5, 4.5), ylim=(-3.5, 3.5))
grid.fig.tight_layout(w_pad=1)

# %%
a4_dims = (11.7, 8.27)
df = mylib.load_data()
fig, ax = pyplot.subplots(figsize=a4_dims)
seaborn.violinplot(ax=ax, data=df, **violin_options)

ax = sns.barplot(x="num", y="num", data=df_final, estimator=lambda x: len(x) / len(df) * 100)
ax.set(ylabel="Percent")

# %%
df_conteos = df_final.num.value_counts()
df_conteos.info()

# %%
sns.set(style="darkgrid")
x= df_conteos.num
ax = sns.distplot(x, bins=43)
