# %% [markdown]
# ### Este libro mostrará un analisis estadistico de la informacion levantada

# %%
import random
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import importlib
import os
from sklearn import metrics
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder, KBinsDiscretizer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from time import sleep


pd.set_option('display.float_format', lambda x: '%.3f' % x)

sns.set()

# %%
def generaPath(tipo, nombre):
    prepath = str(os.getcwd())
    if (tipo == "I"):
        path = prepath + '\\origen\\' + nombre
    else :
        path = prepath + '\\generados\\' + nombre
    return path

# %%
df_cs_tr = pd.read_csv(generaPath('O', 'df_cs_tr.csv'))
df_cd_tr = pd.read_csv(generaPath('O', 'df_cd_tr.csv'))
df_ct_tr = pd.read_csv(generaPath('O', 'df_ct_tr.csv'))
df_cc_tr = pd.read_csv(generaPath('O', 'df_cc_tr.csv'))
df_cq_tr = pd.read_csv(generaPath('O', 'df_cq_tr.csv'))

# %%
df_cs_re = pd.read_csv(generaPath('O', 'df_cs_re.csv'))
df_cd_re = pd.read_csv(generaPath('O', 'df_cd_re.csv'))
df_ct_re = pd.read_csv(generaPath('O', 'df_ct_re.csv'))
df_cc_re = pd.read_csv(generaPath('O', 'df_cc_re.csv'))
df_cq_re = pd.read_csv(generaPath('O', 'df_cq_re.csv'))

# %%
conteos_1d_sb_tr = pd.read_csv(generaPath('O', 'conteos_1d_sb_tr.csv'))
conteos_1d_sb_re = pd.read_csv(generaPath('O', 'conteos_1d_sb_re.csv'))

# %%
def dibujar(datos, sn):
    #importlib.reload(mpl); 
    #importlib.reload(plt); 
    importlib.reload(sns)
    sns.set(style="darkgrid")
    #xs= df_cs_re.conteo
    asx = sn.distplot(datos)

# %%
#def dibujar3(datos, numerito, indexito, df):
    #ordered_info = df.tupla.value_counts().index
    #g = sns.FacetGrid(datos, row_order=ordered_info, height=1.7, aspect=4,)
    #g.map(sns.kdeplot, "conteo")
    #with sns.axes_style("white"):
    #    g = sns.FacetGrid(tips, row="tupla", col="conteo", margin_titles=True, height=100)
    #    g.map(sns.scatterplot, "total_bill", "tip", color="#334488")
    #    g.set_axis_labels("Total bill (US Dollars)", "Tip")
    #    g.set(xticks=[10, 30, 50], yticks=[2, 6, 10])
    #    g.fig.subplots_adjust(wspace=.02, hspace=.02)

# %%
def dibujar2(datos, numerito, indexito, df):
    ordered_info = df.tupla.value_counts().index
    g = sns.FacetGrid(datos, row_order=ordered_info, height=1.7, aspect=4,)
    
    g.map(sns.kdeplot, "conteo")

# %%
def unspliter_tupla(sbs):
    splited = []
    partido = sbs.split(sep='|') if (sbs.find("|") >= 1) else sbs
    #print("partido", partido)
    for x in range(len(partido)):
        splited.append(int(partido[x]))
    return splited

# %%
def deltas_df(df):
    for index, row in df.iterrows():
        sbs = str(row[5])
        numerito = int(row[1])
        splitedtupla= unspliter_tupla(sbs)
        dibujar(splitedtupla, sns)
        #dibujar2(splitedtupla, numerito, index, df)

# %%
deltas_df(df_cs_tr)
# Out:
# C:\Users\Ricardo\.conda\envs\dsbasic\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Ricardo\.conda\envs\dsbasic\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Ricardo\.conda\envs\dsbasic\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Ricardo\.conda\envs\dsbasic\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# C:\Users\Ricardo\.conda\envs\dsbasic\lib\site-packages\numpy\core\_methods.py:140: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# C:\Users\Ricardo\.conda\envs\dsbasic\lib\site-packages\numpy\core\_methods.py:132: RuntimeWarning: invalid value encountered in double_scalars
# ...

# %%
sns.set(style="whitegrid")
xs= df_cs_tr.conteo
print(type(xs))
asx = sns.distplot(xs)
# Out:
# <class 'pandas.core.series.Series'>

# %%
sns.set(style="whitegrid")
xs= df_cs_re.conteo
asx = sns.distplot(xs)

# %%
sns.set(style="whitegrid")
xd= df_cd_re.conteo
ad = sns.distplot(xd)

# %%
sns.set(style="whitegrid")
xd= df_cd_tr.conteo
ad = sns.distplot(xd)

# %%
sns.set(style="whitegrid")
xd= df_ct_tr.conteo
ad = sns.distplot(xd)

# %%
sns.set(style="whitegrid")
xd= df_ct_re.conteo
ad = sns.distplot(xd)

# %%
def get_numbers(df):
    return df
